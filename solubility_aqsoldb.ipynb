# %%
# %pip install PyTDC
# Out:
# Collecting PyTDC
#   Downloading PyTDC-0.4.0.tar.gz (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rdkit-pypi (from PyTDC)
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 37.3 MB/s eta 0:00:00
# Collecting fuzzywuzzy (from PyTDC)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from PyTDC) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from PyTDC) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from PyTDC) (4.65.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from PyTDC) (1.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from PyTDC) (0.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from PyTDC) (2.27.1)
# Collecting huggingface_hub (from PyTDC)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.7 MB/s eta 0:00:00
# Collecting dataclasses (from PyTDC)
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->PyTDC) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->PyTDC) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->PyTDC) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->PyTDC) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->PyTDC) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyTDC) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyTDC) (2022.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi->PyTDC) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->PyTDC) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->PyTDC) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->PyTDC) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->PyTDC) (3.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->PyTDC) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->PyTDC) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->PyTDC) (3.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn->PyTDC) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->PyTDC) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->PyTDC) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->PyTDC) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->PyTDC) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->PyTDC) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->PyTDC) (1.16.0)
# Building wheels for collected packages: PyTDC
#   Building wheel for PyTDC (setup.py) ... done
#   Created wheel for PyTDC: filename=PyTDC-0.4.0-py3-none-any.whl size=139519 sha256=59cdb035f293da67bc48cae8131da6e44762e7350b5e3e6a2cd0581f78c34e37
#   Stored in directory: /root/.cache/pip/wheels/65/da/1a/38e66a2b950c7acc0f41d3bbbc12071653d099baa5402d9c32
# Successfully built PyTDC
# Installing collected packages: fuzzywuzzy, dataclasses, rdkit-pypi, huggingface_hub, PyTDC
# Successfully installed PyTDC-0.4.0 dataclasses-0.6 fuzzywuzzy-0.18.0 huggingface_hub-0.16.4 rdkit-pypi-2022.9.5

# %%
# %pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.2

# %%
# %pip install pandas-flavor
# Out:
# Collecting pandas-flavor
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-flavor) (1.5.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor) (2022.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor) (1.22.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pandas-flavor) (23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-flavor) (1.16.0)
# Installing collected packages: pandas-flavor
# Successfully installed pandas-flavor-0.6.0

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm #progress bar
import rdkit
from rdkit import Chem #Chemistry
from rdkit.Chem import rdMolDescriptors #molecular descriptors
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
rdkit.__version__

import xgboost as xgb
import sklearn
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import fbeta_score, make_scorer
from xgboost.sklearn import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split #ML training
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error #ML stats
from yellowbrick.regressor import prediction_error, ResidualsPlot
from tdc.single_pred import ADME
from tdc.benchmark_group import admet_group
from tdc import BenchmarkGroup
import warnings
warnings.filterwarnings("ignore")

# %%
group = admet_group(path = 'data/')
predictions_list_xgb = []
best_params_list_xgb = []
predictions_list_rf = []
predictions_list_svm = []
best_params_list_svm = []
predictions_list_adb = []
predictions_list_cnn = []

for seed in [1, 2, 3, 4, 5]:
    predictions_xgb = {}
    predictions_rf = {}
    predictions_svm = {}
    predictions_adb = {}
    predictions_cnn = {}

    benchmark = group.get('Solubility_AqSolDB')
    name = benchmark['name']
    train_val, test = benchmark['train_val'], benchmark['test']
    train, valid = group.get_train_valid_split(benchmark = name, split_type = 'default', seed = seed)

    PandasTools.AddMoleculeColumnToFrame(train, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in train['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = train['Y']
    train = pd.DataFrame(ecfp6_bits, index = train.Drug, columns=ecfp6_name).reset_index(drop = False)
    train['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(benchmark['test'], smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in benchmark['test']['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = benchmark['test']['Y']
    benchmark['test'] = pd.DataFrame(ecfp6_bits, index = benchmark['test'].Drug, columns=ecfp6_name).reset_index(drop = False)
    benchmark['test']['Y'] = Y

    train_X = train.drop(columns = ["Drug","Y"])
    train_y = train.Y
    test_X = benchmark['test'].drop(columns = ["Drug","Y"])
    test_y = benchmark['test'].Y


    #XGBoost + Morgan
    xgb_parameters = {'objective':['reg:squarederror'],
              'booster':['gbtree','gblinear'],
              'learning_rate': [0.1],
              'max_depth': [7,10,15,20],
              'min_child_weight': [10,15,20,25],
              'colsample_bytree': [0.8, 0.9, 1],
              'n_estimators': [300,400,500,600],
              "reg_alpha"   : [0.5,0.2,1],
              "reg_lambda"  : [2,3,5],
              "gamma"       : [1,2,3]}

    xgb_model = XGBRegressor()
    grid_obj_xgb = RandomizedSearchCV(xgb_model, xgb_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_xgb.fit(train_X, train_y, verbose = 1)
    y_pred_test_xgb = grid_obj_xgb.predict(test_X)
    bp_xgb = grid_obj_xgb.best_params_
    predictions_xgb[name] = y_pred_test_xgb
    predictions_list_xgb.append(predictions_xgb)
    best_params_list_xgb.append(bp_xgb)

    #Random Forest + Morgan
    rf_model = RandomForestRegressor()
    rf_model.fit(train_X, train_y)
    y_pred_test_rf = rf_model.predict(test_X)
    predictions_rf[name] = y_pred_test_rf
    predictions_list_rf.append(predictions_rf)

    #SVM + Morgan
    svm_parameters = {
        'C': [0.1, 1, 10, 100, 1000],
        'epsilon': [0.0001, 0.001, 0.01, 0.1, 0.5],
        'gamma': [0.0001, 0.001, 0.01, 0.1, 1]
    }
    svm_model = SVR(kernel="rbf")
    grid_obj_svm = RandomizedSearchCV(svm_model, svm_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_svm.fit(train_X, train_y)
    y_pred_test_svm = grid_obj_svm.predict(test_X)
    bp_svm = grid_obj_svm.best_params_
    predictions_svm[name] = y_pred_test_svm
    predictions_list_svm.append(predictions_svm)
    best_params_list_svm.append(bp_svm)

    # AdaBoost + Morgan
    DTR = DecisionTreeRegressor(max_depth=4)
    adb_model = AdaBoostRegressor(n_estimators=300, base_estimator=DTR, learning_rate=1)
    adb_model.fit(train_X, train_y)
    y_pred_test_adb = adb_model.predict(test_X)
    predictions_adb[name] = y_pred_test_adb
    predictions_list_adb.append(predictions_adb)

    #CNN + Morgan
    train_X = train_X.to_numpy()
    test_X = test_X.to_numpy()
    train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], 1)
    test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)
    cnn_model = Sequential()
    cnn_model.add(Conv1D(32, 2, activation="relu", input_shape=(1024,1)))
    cnn_model.add(Flatten())
    cnn_model.add(Dense(64, activation="relu"))
    cnn_model.add(Dense(1))
    cnn_model.compile(loss="mse", optimizer="adam")
    cnn_model.fit(train_X, train_y, batch_size=12, epochs=10, verbose=0)
    y_pred_test_cnn = cnn_model.predict(test_X)
    predictions_cnn[name] = y_pred_test_cnn
    predictions_list_cnn.append(predictions_cnn)

xgb_results = group.evaluate_many(predictions_list_xgb)
rf_results = group.evaluate_many(predictions_list_rf)
svm_results = group.evaluate_many(predictions_list_svm)
adb_results = group.evaluate_many(predictions_list_adb)
cnn_results = group.evaluate_many(predictions_list_cnn)
# Out:
# Downloading Benchmark Group...
# 100%|██████████| 1.47M/1.47M [00:00<00:00, 12.1MiB/s]
# Extracting zip file...
# Done!
# generating training, validation splits...
# 100%|██████████| 7985/7985 [00:06<00:00, 1287.94it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-1.308 total time= 3.9min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-1.317 total time= 3.9min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-1.124 total time= 3.9min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-1.163 total time= 3.9min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.971 total time= 3.9min
# [13:19:00] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.942 total time=  10.6s
# [13:19:10] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-2.624 total time=   8.7s
# [13:19:19] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.871 total time=  10.7s
# [13:19:30] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.798 total time=  10.7s
# [13:19:40] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.359 total time=  10.6s
# [13:19:51] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-1.948 total time=  19.1s
# [13:20:10] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-2.622 total time=  21.2s
# [13:20:31] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-1.862 total time=  18.9s
# [13:20:50] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-1.795 total time=  21.0s
# [13:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-1.355 total time=  20.3s
# [13:21:32] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-1.942 total time=   9.1s
# [13:21:40] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-2.624 total time=  10.6s
# [13:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-1.871 total time=  10.7s
# [13:22:02] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-1.798 total time=  10.7s
# [13:22:13] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-1.359 total time=   8.7s
# [13:22:21] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-1.942 total time=  18.0s
# [13:22:39] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-2.624 total time=  16.1s
# [13:22:55] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-1.871 total time=  16.1s
# [13:23:11] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-1.798 total time=  18.1s
# [13:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-1.359 total time=  16.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.316 total time= 2.1min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.349 total time= 2.1min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.117 total time= 2.1min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.132 total time= 2.1min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.963 total time= 2.1min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.315 total time= 3.9min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.314 total time= 3.9min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.139 total time= 3.9min
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-1.130 total time= 3.9min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.976 total time= 3.9min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.327 total time= 5.8min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1.383 total time= 5.8min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-1
# [CV 2/5] END ..C=10, epsilon=0.1, gamma=0.0001;, score=-1.829 total time=  37.9s
# [CV 3/5] END ..C=10, epsilon=0.1, gamma=0.0001;, score=-1.379 total time=  38.5s
# [CV 4/5] END ..C=10, epsilon=0.1, gamma=0.0001;, score=-1.502 total time=  36.3s
# [CV 5/5] END ..C=10, epsilon=0.1, gamma=0.0001;, score=-1.107 total time=  36.4s
# [CV 1/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-1.557 total time=  40.8s
# [CV 2/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-1.405 total time=  41.1s
# [CV 3/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-1.285 total time=  41.7s
# [CV 4/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-1.283 total time=  43.0s
# [CV 5/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-1.142 total time=  42.0s
# [CV 1/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-1.903 total time=  29.4s
# [CV 2/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-1.855 total time=  27.9s
# [CV 3/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-1.395 total time=  28.3s
# [CV 4/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-1.520 total time=  31.1s
# [CV 5/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-1.122 total time=  30.7s
# [CV 1/5] END .....C=10, epsilon=0.001, gamma=1;, score=-1.832 total time=  40.4s
# [CV 2/5] END .....C=10, epsilon=0.001, gamma=1;, score=-2.452 total time=  38.9s
# [CV 3/5] END .....C=10, epsilon=0.001, gamma=1;, score=-1.816 total time=  40.8s
# [CV 4/5] END .....C=10, epsilon=0.001, gamma=1;, score=-1.787 total time=  42.7s
# [CV 5/5] END .....C=10, epsilon=0.001, gamma=1;, score=-1.343 total time=  42.4s
# [CV 1/5] END ...C=10, epsilon=0.5, gamma=0.001;, score=-1.603 total time=  27.2s
# [CV 2/5] END ...C=10, epsilon=0.5, gamma=0.001;, score=-1.471 total time=  27.6s
# [CV 3/5] END ...C=10, epsilon=0.5, gamma=0.001;, score=-1.183 total time=  27.4s
# [CV 4/5] END ...C=10, epsilon=0.5, gamma=0.001;, score=-1.284 total time=  28.3s
# [CV 5/5] END ...C=10, epsilon=0.5, gamma=0.001;, score=-1.030 total time=  28.4s
# [CV 1/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-2.025 total time=  39.9s
# [CV 2/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-2.418 total time=  39.1s
# [CV 3/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-1.825 total time=  36.6s
# [CV 4/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-1.824 total time=  37.2s
# [CV 5/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-1.402 total time=  38.8s
# [CV 1/5] END ......C=10, epsilon=0.01, gamma=1;, score=-1.832 total time=  39.7s
# [CV 2/5] END ......C=10, epsilon=0.01, gamma=1;, score=-2.453 total time=  38.9s
# [CV 3/5] END ......C=10, epsilon=0.01, gamma=1;, score=-1.816 total time=  40.3s
# [CV 4/5] END ......C=10, epsilon=0.01, gamma=1;, score=-1.787 total time=  40.5s
# [CV 5/5] END ......C=10, epsilon=0.01, gamma=1;, score=-1.343 total time=  39.4s
# [CV 1/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.857 total time=  39.1s
# [CV 2/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.748 total time=  37.5s
# [CV 3/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.461 total time=  40.6s
# [CV 4/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.583 total time=  39.9s
# [CV 5/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.186 total time=  39.4s
# [CV 1/5] END .....C=1, epsilon=0.1, gamma=0.01;, score=-1.570 total time=  36.2s
# [CV 2/5] END .....C=1, epsilon=0.1, gamma=0.01;, score=-1.410 total time=  37.3s
# [CV 3/5] END .....C=1, epsilon=0.1, gamma=0.01;, score=-1.154 total time=  37.9s
# [CV 4/5] END .....C=1, epsilon=0.1, gamma=0.01;, score=-1.250 total time=  37.9s
# [CV 5/5] END .....C=1, epsilon=0.1, gamma=0.01;, score=
5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-1.234 total time=  28.4s
# [CV 5/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-1.379 total time=  29.2s
# [CV 1/5] END .C=100, epsilon=0.1, gamma=0.0001;, score=-1.370 total time=  36.8s
# [CV 2/5] END .C=100, epsilon=0.1, gamma=0.0001;, score=-1.060 total time=  37.4s
# [CV 3/5] END .C=100, epsilon=0.1, gamma=0.0001;, score=-1.452 total time=  38.3s
# [CV 4/5] END .C=100, epsilon=0.1, gamma=0.0001;, score=-1.346 total time=  38.3s
# [CV 5/5] END .C=100, epsilon=0.1, gamma=0.0001;, score=-1.292 total time=  38.1s
# [CV 1/5] END ...C=1000, epsilon=0.001, gamma=1;, score=-2.000 total time=  39.9s
# [CV 2/5] END ...C=1000, epsilon=0.001, gamma=1;, score=-1.280 total time=  39.6s
# [CV 3/5] END ...C=1000, epsilon=0.001, gamma=1;, score=-1.911 total time=  38.9s
# [CV 4/5] END ...C=1000, epsilon=0.001, gamma=1;, score=-2.219 total time=  40.2s
# [CV 5/5] END ...C=1000, epsilon=0.001, gamma=1;, score=-1.820 total time=  41.0s
# [CV 1/5] END C=1000, epsilon=0.001, gamma=0.01;, score=-1.335 total time=  57.0s
# [CV 2/5] END C=1000, epsilon=0.001, gamma=0.01;, score=-1.216 total time= 1.0min
# [CV 3/5] END C=1000, epsilon=0.001, gamma=0.01;, score=-1.452 total time=  58.3s
# [CV 4/5] END C=1000, epsilon=0.001, gamma=0.01;, score=-1.347 total time=  59.1s
# [CV 5/5] END C=1000, epsilon=0.001, gamma=0.01;, score=-1.632 total time= 1.0min
# [CV 1/5] END C=100, epsilon=0.01, gamma=0.0001;, score=-1.370 total time=  38.5s
# [CV 2/5] END C=100, epsilon=0.01, gamma=0.0001;, score=-1.063 total time=  39.8s
# [CV 3/5] END C=100, epsilon=0.01, gamma=0.0001;, score=-1.451 total time=  38.2s
# [CV 4/5] END C=100, epsilon=0.01, gamma=0.0001;, score=-1.346 total time=  38.0s
# [CV 5/5] END C=100, epsilon=0.01, gamma=0.0001;, score=-1.293 total time=  40.5s
# [CV 1/5] END ....C=100, epsilon=0.001, gamma=1;, score=-2.000 total time=  41.6s
# [CV 2/5] END ....C=100, epsilon=0.001, gamma=1;, score=-1.280 total time=  41.3s
# [CV 3/5] END ....C=100, epsilon=0.001, gamma=1;, score=-1.911 total time=  41.7s
# [CV 4/5] END ....C=100, epsilon=0.001, gamma=1;, score=-2.219 total time=  40.5s
# [CV 5/5] END ....C=100, epsilon=0.001, gamma=1;, score=-1.820 total time=  41.1s
# [CV 1/5] END .C=100, epsilon=0.5, gamma=0.0001;, score=-1.357 total time=  27.4s
# [CV 2/5] END .C=100, epsilon=0.5, gamma=0.0001;, score=-1.080 total time=  26.7s
# [CV 3/5] END .C=100, epsilon=0.5, gamma=0.0001;, score=-1.448 total time=  25.7s
# [CV 4/5] END .C=100, epsilon=0.5, gamma=0.0001;, score=-1.363 total time=  25.8s
# [CV 5/5] END .C=100, epsilon=0.5, gamma=0.0001;, score=-1.295 total time=  26.4s
# [CV 1/5] END C=1000, epsilon=0.01, gamma=0.001;, score=-1.218 total time=  59.5s
# [CV 2/5] END C=1000, epsilon=0.01, gamma=0.001;, score=-0.996 total time= 1.0min

# %%
xgb_results

# %%
rf_results

# %%
svm_results

# %%
adb_results

# %%
cnn_results

# %%
predictions_list_xgb

# %%
predictions_list_rf

# %%
predictions_list_svm

# %%
predictions_list_adb

# %%
predictions_list_cnn
