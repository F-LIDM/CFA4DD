# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm #progress bar
import rdkit
from rdkit import Chem #Chemistry
from rdkit.Chem import rdMolDescriptors #molecular descriptors
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
rdkit.__version__

import xgboost as xgb
import sklearn
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import fbeta_score, make_scorer
from xgboost.sklearn import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split #ML training
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error #ML stats
from tdc.single_pred import ADME
from tdc.benchmark_group import admet_group

from tdc import BenchmarkGroup
import warnings
warnings.filterwarnings("ignore")

# %%
group = admet_group(path = 'data/')

pred_valid_list_xgb = []
pred_valid_list_rf = []
pred_valid_list_svm = []
pred_valid_list_adb = []
pred_valid_list_cnn = []
        
pred_test_list_xgb = []
pred_test_list_rf = []
pred_test_list_svm = []
pred_test_list_adb = []
pred_test_list_cnn = []

best_params_list_xgb = []
best_params_list_svm = []

for seed in [1, 2, 3, 4, 5]:
    pred_valid_xgb = {}
    pred_valid_rf = {}
    pred_valid_svm = {}
    pred_valid_adb = {}
    pred_valid_cnn = {}

    pred_test_xgb = {}
    pred_test_rf = {}
    pred_test_svm = {}
    pred_test_adb = {}
    pred_test_cnn = {}

    benchmark = group.get('Caco2_Wang')
    name = benchmark['name']
    train_val, test = benchmark['train_val'], benchmark['test']
    train, valid = group.get_train_valid_split(benchmark = name, split_type = 'default', seed = seed)

    PandasTools.AddMoleculeColumnToFrame(train, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in train['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = train['Y']
    train = pd.DataFrame(ecfp6_bits, index = train.Drug, columns=ecfp6_name).reset_index(drop = False)
    train['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(valid, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in valid['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = valid['Y']
    valid = pd.DataFrame(ecfp6_bits, index = valid.Drug, columns=ecfp6_name).reset_index(drop = False)
    valid['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(benchmark['test'], smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in benchmark['test']['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = benchmark['test']['Y']
    benchmark['test'] = pd.DataFrame(ecfp6_bits, index = benchmark['test'].Drug, columns=ecfp6_name).reset_index(drop = False)
    benchmark['test']['Y'] = Y

    train_X = train.drop(columns = ["Drug","Y"])
    train_y = train.Y
    valid_X = valid.drop(columns = ["Drug","Y"])
    globals()['valid_y_%s'%seed] = valid.Y
    test_X = benchmark['test'].drop(columns = ["Drug","Y"])
    test_y = benchmark['test'].Y

    
    #XGBoost + Morgan
    xgb_parameters = {'objective':['reg:squarederror'],
            'booster':['gbtree','gblinear'],
            'learning_rate': [0.1],
            'max_depth': [7,10,15,20],
            'min_child_weight': [10,15,20,25],
            'colsample_bytree': [0.8, 0.9, 1],
            'n_estimators': [300,400,500,600],
            "reg_alpha"   : [0.5,0.2,1],
            "reg_lambda"  : [2,3,5],
            "gamma"       : [1,2,3]}

    xgb_model = XGBRegressor()
    grid_obj_xgb = RandomizedSearchCV(xgb_model, xgb_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_xgb.fit(train_X, train_y, verbose = 1)
    y_pred_valid_xgb = grid_obj_xgb.predict(valid_X)
    y_pred_test_xgb = grid_obj_xgb.predict(test_X)
    pred_valid_xgb[name] = y_pred_valid_xgb
    pred_valid_list_xgb.append(pred_valid_xgb)
    pred_test_xgb[name] = y_pred_test_xgb
    pred_test_list_xgb.append(pred_test_xgb)
    bp_xgb = grid_obj_xgb.best_params_
    best_params_list_xgb.append(bp_xgb)

    #Random Forest + Morgan
    rf_model = RandomForestRegressor()
    rf_model.fit(train_X, train_y)
    y_pred_valid_rf = rf_model.predict(valid_X)
    y_pred_test_rf = rf_model.predict(test_X)
    pred_valid_rf[name] = y_pred_valid_rf
    pred_valid_list_rf.append(pred_valid_rf)
    pred_test_rf[name] = y_pred_test_rf
    pred_test_list_rf.append(pred_test_rf)

    #SVM + Morgan
    svm_parameters = {
        'C': [0.1, 1, 10, 100, 1000],
        'epsilon': [0.0001, 0.001, 0.01, 0.1, 0.5],
        'gamma': [0.0001, 0.001, 0.01, 0.1, 1]
    }
    svm_model = SVR(kernel="rbf")
    grid_obj_svm = RandomizedSearchCV(svm_model, svm_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_svm.fit(train_X, train_y)
    y_pred_valid_svm = grid_obj_svm.predict(valid_X)
    y_pred_test_svm = grid_obj_svm.predict(test_X)
    pred_valid_svm[name] = y_pred_valid_svm
    pred_valid_list_svm.append(pred_valid_svm)
    pred_test_svm[name] = y_pred_test_svm
    pred_test_list_svm.append(pred_test_svm)
    bp_svm = grid_obj_svm.best_params_
    best_params_list_svm.append(bp_svm)
    
    #AdaBoost + Morgan
    DTR = DecisionTreeRegressor(max_depth=4)
    adb_model = AdaBoostRegressor(n_estimators=300, base_estimator=DTR, learning_rate=1)
    adb_model.fit(train_X, train_y)
    y_pred_valid_adb = adb_model.predict(valid_X)
    y_pred_test_adb = adb_model.predict(test_X)
    pred_valid_adb[name] = y_pred_valid_adb
    pred_valid_list_adb.append(pred_valid_adb)
    pred_test_adb[name] = y_pred_test_adb
    pred_test_list_adb.append(pred_test_adb)

    '''
    #for GCN, refer to https://github.com/kexinhuang12345/DeepPurpose
    #GCN
    drug_encoding = 'DGL_GCN'
    benchmark = group.get('Half_Life_Obach')
    train_gcn, valid_gcn = group.get_train_valid_split(benchmark = benchmark['name'], split_type = 'default', seed = seed)
    train_gcn = data_process(X_drug = train_gcn.Drug.values, y = train_gcn.Y.values, drug_encoding = drug_encoding, split_method='no_split')
    val_gcn = data_process(X_drug = valid_gcn.Drug.values, y = valid_gcn.Y.values, drug_encoding = drug_encoding, split_method='no_split')
    test_gcn = data_process(X_drug = benchmark['test'].Drug.values, y = benchmark['test'].Y.values, drug_encoding = drug_encoding, split_method='no_split')
    config = generate_config(drug_encoding = drug_encoding,
                            cls_hidden_dims = [512],
                            train_epoch = 10,
                            LR = 0.001,
                            batch_size = 128,
                            )

    gcn_model = models.model_initialize(**config)
    gcn_model.train(train_gcn, val_gcn, test_gcn, verbose = True)
    y_pred_test_gcn = gcn_model.predict(test_gcn)
    predictions_gcn[name] = y_pred_test_gcn
    predictions_list_gcn.append(predictions_gcn)
    '''

    #CNN + Morgan
    train_X_cnn = train_X.to_numpy()
    valid_X_cnn = valid_X.to_numpy()
    test_X_cnn = test_X.to_numpy()
    train_X_cnn = train_X_cnn.reshape(train_X_cnn.shape[0], train_X_cnn.shape[1], 1)
    valid_X_cnn = valid_X_cnn.reshape(valid_X_cnn.shape[0], valid_X_cnn.shape[1], 1)
    test_X_cnn = test_X_cnn.reshape(test_X_cnn.shape[0], test_X_cnn.shape[1], 1)
    cnn_model = Sequential()
    cnn_model.add(Conv1D(32, 2, activation="relu", input_shape=(1024,1)))
    cnn_model.add(Flatten())
    cnn_model.add(Dense(64, activation="relu"))
    cnn_model.add(Dense(1))
    cnn_model.compile(loss="mse", optimizer="adam")
    cnn_model.fit(train_X_cnn, train_y, batch_size=12, epochs=10, verbose=0)
    y_pred_valid_cnn = cnn_model.predict(valid_X_cnn)
    y_pred_test_cnn = cnn_model.predict(test_X_cnn)
    y_pred_valid_cnn_copy = []
    for i in range(len(y_pred_valid_cnn)):
        y_pred_valid_cnn_copy.append(y_pred_valid_cnn[i][0])
    y_pred_test_cnn_copy = []
    for i in range(len(y_pred_test_cnn)):
        y_pred_test_cnn_copy.append(y_pred_test_cnn[i][0])
    pred_valid_cnn[name] = np.array(y_pred_valid_cnn_copy)
    pred_valid_list_cnn.append(pred_valid_cnn)
    pred_test_cnn[name] = np.array(y_pred_test_cnn_copy)
    pred_test_list_cnn.append(pred_test_cnn)


xgb_perform = group.evaluate_many(pred_test_list_xgb)
rf_perform = group.evaluate_many(pred_test_list_rf)
svm_perform = group.evaluate_many(pred_test_list_svm)
adb_perform = group.evaluate_many(pred_test_list_adb)
cnn_perform = group.evaluate_many(pred_test_list_cnn)
# Out:
# Found local copy...
# generating training, validation splits...
# 100%|██████████| 728/728 [00:00<00:00, 2022.64it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [03:20:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.580 total time=   0.8s
# [03:20:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.683 total time=   0.8s
# [03:20:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.645 total time=   0.8s
# [03:20:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.671 total time=   0.9s
# [03:20:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.649 total time=   0.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.445 total time=   4.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.493 total time=   4.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.481 total time=   4.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.544 total time=   3.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.469 total time=   4.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.422 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.510 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.499 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.535 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.473 total time=   1.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.418 total time=   2.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.508 total time=   2.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.487 total time=   2.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.546 total time=   2.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.455 total time=   2.0s
# [03:21:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.580 total time=   1.0s
# [03:21:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.683 total time=   1.0s
# [03:21:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.645 total time=   1.0s
# [03:21:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.671 total time=   1.0s
# [03:21:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.649 total time=   1.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.479 total time=   5.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.528 total time=   5.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.503 total time=   5.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.566 total time=   5.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.489 total time=   5.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.420 total time=   3.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.509 total time=   3.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.465 total time=   3.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.507 total time=   3.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.446 total time=   3.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.426 total time=   4.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.499 total time=   4.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.480 total time=   4.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.529 total time=   4.3s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.449 total time=   4.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.451 total time=   4.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.534 total time=   4.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.512 total time=   4.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.555 total time=   4.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.490 total time=   4.2s
# [03:22:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.580 total time=   1.0s
# [03:22:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.683 total time=   1.0s
# [03:22:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.645 total time=   1.1s
# [03:22:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.671 total time=   1.1s
# [03:22:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.649 total time=   1.1s
# [03:22:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.580 total time=   1.4s
# [03:22:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.683 total time=   1.4s
# [03:22:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.645 total time=   1.5s
# [03:22:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.671 total time=   1.5s
# [03:22:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.649 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.416 total time=   4.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.502 total time=   4.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.479 total time=   4.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.521 total time=   4.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.454 total time=   4.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.452 total time=   5.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.516 total time=   5.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.478 total time=   4.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.512 total time=   4.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.449 total time=   4.6s
# [03:23:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.580 total time=   1.6s
# [03:23:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.683 total time=   1.5s
# [03:23:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.645 total time=   1.5s
# [03:23:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.671 total time=   1.8s
# [03:23:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.649 total time=   1.6s
# [03:23:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-0.580 total time=   1.1s
# [03:23:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-0.683 total time=   1.1s
# [03:23:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-0.645 total time=   1.1s
# [03:23:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-0.671 total time=   1.1s
# [03:23:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-0.649 total time=   1.1s
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.551 total time=   0.1s
# [CV 2/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.625 total time=   0.1s
# [CV 3/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.581 total time=   0.1s
# [CV 4/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.580 total time=   0.1s
# [CV 5/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.512 total time=   0.1s
# [CV 1/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-0.581 total time=   0.1s
# [CV 2/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-0.684 total time=   0.1s
# [CV 3/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-0.648 total time=   0.1s
# [CV 4/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-0.658 total time=   0.1s
# [CV 5/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-0.639 total time=   0.1s
# [CV 1/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-0.565 total time=   0.1s
# [CV 2/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-0.679 total time=   0.1s
# [CV 3/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-0.631 total time=   0.1s
# [CV 4/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-0.662 total time=   0.1s
# [CV 5/5] END .C=0.1, epsilon=0.1, gamma=0.0001;, score=-0.641 total time=   0.1s
# [CV 1/5] END ....C=1, epsilon=0.5, gamma=0.001;, score=-0.526 total time=   0.1s
# [CV 2/5] END ....C=1, epsilon=0.5, gamma=0.001;, score=-0.589 total time=   0.1s
# [CV 3/5] END ....C=1, epsilon=0.5, gamma=0.001;, score=-0.540 total time=   0.1s
# [CV 4/5] END ....C=1, epsilon=0.5, gamma=0.001;, score=-0.586 total time=   0.1s
# [CV 5/5] END ....C=1, epsilon=0.5, gamma=0.001;, score=-0.564 total time=   0.1s
# [CV 1/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.503 total time=   0.1s
# [CV 2/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.555 total time=   0.1s
# [CV 3/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.526 total time=   0.1s
# [CV 4/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.569 total time=   0.1s
# [CV 5/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.533 total time=   0.1s
# [CV 1/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.503 total time=   0.1s
# [CV 2/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.559 total time=   0.1s
# [CV 3/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.526 total time=   0.1s
# [CV 4/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.570 total time=   0.1s
# [CV 5/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.533 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.667 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.597 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.460 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.550 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.577 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.001, gamma=0.0001;, score=-0.676 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.001, gamma=0.0001;, score=-0.600 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.001, gamma=0.0001;, score=-0.459 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.001, gamma=0.0001;, score=-0.553 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.001, gamma=0.0001;, score=-0.578 total time=   0.1s
# [CV 1/5] END ..C=1, epsilon=0.01, gamma=0.0001;, score=-0.553 total time=   0.1s
# [CV 2/5] END ..C=1, epsilon=0.01, gamma=0.0001;, score=-0.662 total time=   0.1s
# [CV 3/5] END ..C=1, epsilon=0.01, gamma=0.0001;, score=-0.615 total time=   0.1s
# [CV 4/5] END ..C=1, epsilon=0.01, gamma=0.0001;, score=-0.649 total time=   0.1s
# [CV 5/5] END ..C=1, epsilon=0.01, gamma=0.0001;, score=-0.624 total time=   0.1s
# [CV 1/5] END ..C=100, epsilon=0.01, gamma=0.01;, score=-0.430 total time=   0.1s
# [CV 2/5] END ..C=100, epsilon=0.01, gamma=0.01;, score=-0.483 total time=   0.1s
# [CV 3/5] END ..C=100, epsilon=0.01, gamma=0.01;, score=-0.413 total time=   0.1s
# [CV 4/5] END ..C=100, epsilon=0.01, gamma=0.01;, score=-0.443 total time=   0.1s
# [CV 5/5] END ..C=100, epsilon=0.01, gamma=0.01;, score=-0.449 total time=   0.1s
# [CV 1/5] END ....C=100, epsilon=0.001, gamma=1;, score=-0.579 total time=   0.1s
# [CV 2/5] END ....C=100, epsilon=0.001, gamma=1;, score=-0.683 total time=   0.1s
# [CV 3/5] END ....C=100, epsilon=0.001, gamma=1;, score=-0.646 total time=   0.1s
# [CV 4/5] END ....C=100, epsilon=0.001, gamma=1;, score=-0.656 total time=   0.1s
# [CV 5/5] END ....C=100, epsilon=0.001, gamma=1;, score=-0.638 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.432 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.484 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.412 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.444 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.451 total time=   0.1s
# [CV 1/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-0.566 total time=   0.1s
# [CV 2/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-0.681 total time=   0.1s
# [CV 3/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-0.633 total time=   0.1s
# [CV 4/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-0.661 total time=   0.1s
# [CV 5/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-0.640 total time=   0.1s
# [CV 1/5] END ......C=1, epsilon=0.5, gamma=0.1;, score=-0.586 total time=   0.1s
# [CV 2/5] END ......C=1, epsilon=0.5, gamma=0.1;, score=-0.665 total time=   0.1s
# [CV 3/5] END ......C=1, epsilon=0.5, gamma=0.1;, score=-0.618 total time=   0.1s
# [CV 4/5] END ......C=1, epsilon=0.5, gamma=0.1;, score=-0.631 total time=   0.1s
# [CV 5/5] END ......C=1, epsilon=0.5, gamma=0.1;, score=-0.576 total time=   0.1s
# [CV 1/5] END C=0.1, epsilon=0.001, gamma=0.0001;, score=-0.565 total time=   0.1s
# [CV 2/5] END C=0.1, epsilon=0.001, gamma=0.0001;, score=-0.678 total time=   0.1s
# [CV 3/5] END C=0.1, epsilon=0.001, gamma=0.0001;, score=-0.631 total time=   0.1s
# [CV 4/5] END C=0.1, epsilon=0.001, gamma=0.0001;, score=-0.663 total time=   0.1s
# [CV 5/5] END C=0.1, epsilon=0.001, gamma=0.0001;, score=-0.641 total time=   0.1s
# 3/3 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# generating training, validation splits...
# 100%|██████████| 728/728 [00:00<00:00, 2069.74it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [03:24:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.663 total time=   1.5s
# [03:24:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.604 total time=   1.5s
# [03:24:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.630 total time=   1.5s
# [03:24:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.610 total time=   1.5s
# [03:24:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.714 total time=   1.4s
# [03:24:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.663 total time=   1.5s
# [03:24:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.604 total time=   1.5s
# [03:24:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.630 total time=   1.5s
# [03:24:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.610 total time=   1.5s
# [03:24:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.714 total time=   1.5s
# [03:24:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.663 total time=   1.5s
# [03:24:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.604 total time=   1.5s
# [03:24:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.630 total time=   1.5s
# [03:24:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.610 total time=   1.5s
# [03:24:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.714 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.536 total time=   3.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.448 total time=   3.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.484 total time=   3.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.521 total time=   3.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.583 total time=   3.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.481 total time=   2.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.435 total time=   2.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.444 total time=   2.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.522 total time=   2.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.544 total time=   2.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.462 total time=   5.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.400 total time=   5.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.424 total time=   4.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.482 total time=   4.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-0.541 total time=   4.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.470 total time=   3.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.399 total time=   3.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.426 total time=   3.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.510 total time=   3.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-0.542 total time=   3.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.497 total time=   3.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.456 total time=   3.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.446 total time=   3.3s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.522 total time=   3.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-0.574 total time=   3.2s
# [03:26:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.663 total time=   1.1s
# [03:26:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.604 total time=   1.1s
# [03:26:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.630 total time=   1.1s
# [03:26:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.610 total time=   1.1s
# [03:26:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.714 total time=   1.1s
# [03:26:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.663 total time=   1.2s
# [03:26:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.604 total time=   1.2s
# [03:26:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.630 total time=   1.2s
# [03:26:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.610 total time=   1.3s
# [03:26:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-0.714 total time=   1.2s
# [03:26:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.663 total time=   1.0s
# [03:26:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-0.604 total time=   1.1s
# ...
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.640 total time=   1.2s
# [03:39:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.572 total time=   1.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.480 total time=   8.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.496 total time=   9.3s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.503 total time=  11.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.439 total time=  10.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-0.425 total time=   9.5s
# [03:40:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.716 total time=   1.6s
# [03:40:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.592 total time=   1.8s
# [03:40:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.719 total time=   1.7s
# [03:40:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.640 total time=   1.9s
# [03:40:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.572 total time=   1.7s
# [03:40:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.716 total time=   1.4s
# [03:40:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.592 total time=   1.8s
# [03:40:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.719 total time=   1.5s
# [03:40:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.640 total time=   1.5s
# [03:40:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.572 total time=   1.3s
# [03:40:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.716 total time=   1.7s
# [03:40:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.592 total time=   1.6s
# [03:40:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.719 total time=   1.7s
# [03:40:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.640 total time=   1.7s
# [03:40:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-0.572 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.486 total time=  11.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.494 total time=  10.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.514 total time=  10.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.444 total time=  12.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-0.426 total time=  12.0s
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.480 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.533 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.598 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.513 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-0.484 total time=   0.1s
# [CV 1/5] END .C=1, epsilon=0.001, gamma=0.0001;, score=-0.725 total time=   0.1s
# [CV 2/5] END .C=1, epsilon=0.001, gamma=0.0001;, score=-0.548 total time=   0.1s
# [CV 3/5] END .C=1, epsilon=0.001, gamma=0.0001;, score=-0.667 total time=   0.1s
# [CV 4/5] END .C=1, epsilon=0.001, gamma=0.0001;, score=-0.629 total time=   0.1s
# [CV 5/5] END .C=1, epsilon=0.001, gamma=0.0001;, score=-0.535 total time=   0.1s
# [CV 1/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-0.634 total time=   0.1s
# [CV 2/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-0.541 total time=   0.1s
# [CV 3/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-0.634 total time=   0.1s
# [CV 4/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-0.535 total time=   0.1s
# [CV 5/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-0.526 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.389 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.419 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.464 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.413 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.0001, gamma=0.01;, score=-0.417 total time=   0.1s
# [CV 1/5] END ......C=10, epsilon=0.01, gamma=1;, score=-0.714 total time=   0.1s
# [CV 2/5] END ......C=10, epsilon=0.01, gamma=1;, score=-0.588 total time=   0.1s
# [CV 3/5] END ......C=10, epsilon=0.01, gamma=1;, score=-0.720 total time=   0.1s
# [CV 4/5] END ......C=10, epsilon=0.01, gamma=1;, score=-0.639 total time=   0.1s
# [CV 5/5] END ......C=10, epsilon=0.01, gamma=1;, score=-0.571 total time=   0.1s
# [CV 1/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-0.598 total time=   0.1s
# [CV 2/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-0.493 total time=   0.1s
# [CV 3/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-0.554 total time=   0.1s
# [CV 4/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-0.518 total time=   0.1s
# [CV 5/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-0.464 total time=   0.1s
# [CV 1/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.598 total time=   0.1s
# [CV 2/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.492 total time=   0.1s
# [CV 3/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.554 total time=   0.1s
# [CV 4/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.517 total time=   0.1s
# [CV 5/5] END C=10, epsilon=0.001, gamma=0.0001;, score=-0.464 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-0.442 total time=   0.1s
# [CV 2/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-0.480 total time=   0.1s
# [CV 3/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-0.562 total time=   0.1s
# [CV 4/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-0.487 total time=   0.1s
# [CV 5/5] END C=1000, epsilon=0.1, gamma=0.0001;, score=-0.483 total time=   0.1s
# [CV 1/5] END .....C=100, epsilon=0.01, gamma=1;, score=-0.714 total time=   0.1s
# [CV 2/5] END .....C=100, epsilon=0.01, gamma=1;, score=-0.588 total time=   0.1s
# [CV 3/5] END .....C=100, epsilon=0.01, gamma=1;, score=-0.720 total time=   0.1s
# [CV 4/5] END .....C=100, epsilon=0.01, gamma=1;, score=-0.639 total time=   0.1s
# [CV 5/5] END .....C=100, epsilon=0.01, gamma=1;, score=-0.571 total time=   0.1s
# [CV 1/5] END C=0.1, epsilon=0.0001, gamma=0.01;, score=-0.629 total time=   0.1s
# [CV 2/5] END C=0.1, epsilon=0.0001, gamma=0.01;, score=-0.505 total time=   0.1s
# [CV 3/5] END C=0.1, epsilon=0.0001, gamma=0.01;, score=-0.580 total time=   0.1s
# [CV 4/5] END C=0.1, epsilon=0.0001, gamma=0.01;, score=-0.539 total time=   0.1s
# [CV 5/5] END C=0.1, epsilon=0.0001, gamma=0.01;, score=-0.478 total time=   0.1s
# [CV 1/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.635 total time=   0.1s
# [CV 2/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.542 total time=   0.1s
# [CV 3/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.634 total time=   0.1s
# [CV 4/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.535 total time=   0.1s
# [CV 5/5] END ....C=10, epsilon=0.01, gamma=0.1;, score=-0.526 total time=   0.1s
# [CV 1/5] END ..C=1, epsilon=0.001, gamma=0.001;, score=-0.600 total time=   0.1s
# [CV 2/5] END ..C=1, epsilon=0.001, gamma=0.001;, score=-0.492 total time=   0.1s
# [CV 3/5] END ..C=1, epsilon=0.001, gamma=0.001;, score=-0.556 total time=   0.1s
# [CV 4/5] END ..C=1, epsilon=0.001, gamma=0.001;, score=-0.518 total time=   0.1s
# [CV 5/5] END ..C=1, epsilon=0.001, gamma=0.001;, score=-0.465 total time=   0.1s
# [CV 1/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.600 total time=   0.1s
# [CV 2/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.492 total time=   0.1s
# [CV 3/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.556 total time=   0.1s
# [CV 4/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.518 total time=   0.1s
# [CV 5/5] END .C=1, epsilon=0.0001, gamma=0.001;, score=-0.465 total time=   0.1s
# [CV 1/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-0.443 total time=   0.1s
# [CV 2/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-0.501 total time=   0.1s
# [CV 3/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-0.567 total time=   0.1s
# [CV 4/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-0.482 total time=   0.1s
# [CV 5/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-0.460 total time=   0.1s
# [CV 1/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-0.704 total time=   0.1s
# [CV 2/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-0.566 total time=   0.1s
# [CV 3/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-0.686 total time=   0.1s
# [CV 4/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-0.622 total time=   0.1s
# [CV 5/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-0.552 total time=   0.1s
# 3/3 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
print("xgb_perform:", xgb_perform, "\n rf_perform:", rf_perform, "\n svm_perform:", svm_perform, "\n adb_perform:", adb_perform, "\n cnn_perform:", cnn_perform)
# Out:
# xgb_perform: {'caco2_wang': [0.512, 0.02]}
#  rf_perform: {'caco2_wang': [0.454, 0.018]}
#  svm_perform: {'caco2_wang': [0.418, 0.028]}
#  adb_perform: {'caco2_wang': [0.49, 0.015]}
#  cnn_perform: {'caco2_wang': [0.716, 0.078]}

# %%
y_test = benchmark['test'].Y
y_test = np.array(y_test)

# %%
def rank_object(array): # convert scores into ranks
    arg_a = np.argsort(array)
    b = np.flip(np.arange(len(arg_a)))
    a = np.zeros_like(arg_a)
    for i in range(len(arg_a)):
        a[arg_a[i]] = b[i]
    return a

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
def normalize(array): # define function for normalization of scores
    maximum = np.max(array)
    minimum = np.min(array)
    norm_list = []
    for i in range(len(array)):
        norm_list.append((array[i]-minimum)/(maximum-minimum))
    return np.array(norm_list)

# %%
predictions_valid_xgb = []
predictions_valid_rf = []
predictions_valid_svm = []
predictions_valid_adb = []
predictions_valid_cnn = []

predictions_test_xgb = []
predictions_test_rf = []
predictions_test_svm = []
predictions_test_adb = []
predictions_test_cnn = []

scoreSys = ['xgb', 'rf', 'svm', 'adb', 'cnn']

for sys in scoreSys:
  for seed in range(len(globals()['pred_valid_list_%s' % sys])):
    globals()['predictions_valid_%s' % sys].append(list(globals()['pred_valid_list_%s' % sys][seed].values())[0])

for sys in scoreSys:
  for seed in range(len(globals()['pred_test_list_%s' % sys])):
    globals()['predictions_test_%s' % sys].append(list(globals()['pred_test_list_%s' % sys][seed].values())[0])

# %%
# RSC graphs
colors = ['r--', 'm--', 'b--', 'g--', 'y--']

for seed in range(len(globals()['predictions_valid_%s' % sys])):
  fig, ax = plt.subplots()
  ranks = np.flip(np.arange(len(predictions_valid_xgb[seed])))
  for z in range(len(scoreSys)):
    globals()['line%s' % (z+1)] = plt.plot(ranks, np.sort(normalize(globals()['predictions_valid_%s' % scoreSys[z]][seed])), colors[z], label = scoreSys[z])
    plt.legend(loc = 'upper right')
    plt.title('RSC Graphs of Base Models - Seed %s' % str(seed+1))
    plt.xlabel('Rank Value')
    plt.ylabel('Normalized Score')
  plt.show()
  image_name = benchmark['name'] + '_morgan_rsc_seed_%s'% str(seed+1) + '.png'
  image_format = 'png'
  fig.savefig(image_name, format=image_format, dpi=1200)

# %%
ds_score = [[] for _ in range(5)]
for sys in scoreSys:
  for seed in range(len(ds_score)):
    loc = scoreSys.index(sys)
    scoreSys.remove(sys)
    ds = 0
    for i in range(len(scoreSys)):
      ds += np.sum(np.square(normalize(np.sort(globals()['predictions_valid_%s' % sys][seed]))-normalize(np.sort(globals()['predictions_valid_%s' % scoreSys[i]][seed]))))
    ds = ds/len(scoreSys)
    scoreSys.insert(loc, sys)
    ds_score[seed].append(ds)

# %%
ds_score
# Out:
# [[1.0197121003547207,
#   1.112083779564193,
#   1.4384818141152802,
#   3.622568832334246,
#   2.330688802861289],
#  [0.9222806399078096,
#   0.8267861145915476,
#   1.759277720929667,
#   2.908733938239863,
#   1.0327188410955521],
#  [0.4261178569542713,
#   0.515297184062824,
#   0.5672927935853574,
#   1.1436288058840889,
#   0.7287125088853981],
#  [0.7802398835892836,
#   0.8790957513908411,
#   1.2868301402597373,
#   2.693151614451184,
#   1.4336921313188604],
#  [0.7812271438289432,
#   0.6528983902461707,
#   1.6558248081738762,
#   1.3738819705713972,
#   0.8458018356348039]]

# %%
ds_rank = np.reciprocal(ds_score)

# %%
ds_rank
# Out:
# array([[0.98066896, 0.89921283, 0.69517737, 0.2760472 , 0.42905771],
#        [1.08426867, 1.20950265, 0.56841509, 0.34379219, 0.96831776],
#        [2.34676858, 1.94062772, 1.76275816, 0.87440959, 1.37228329],
#        [1.28165712, 1.13753251, 0.77710334, 0.37131218, 0.69749982],
#        [1.28003745, 1.5316319 , 0.60392863, 0.72786456, 1.18231004]])

# %%
def mean_absolute_error(y_pred, y_true):
  res = np.mean(np.abs(y_pred - y_true))
  return res

# %%
ps_score = [[] for _ in range(5)]

# %%
def spearman_corr(y_pred_rank, y_true_rank):
  n = len(y_pred_rank)
  res = 1 - 6 * np.sum((y_pred_rank - y_true_rank)**2) / (n*(n**2-1))
  return res

# %%
for sys in scoreSys:
  for seed in range(len(ps_score)):
    ps = mean_absolute_error(globals()['predictions_valid_%s' % sys][seed], globals()['valid_y_%s'%str(seed+1)])
    ps_score[seed].append(ps)

# %%
ps_score
# Out:
# [[0.3852555797111093,
#   0.44672219801666696,
#   0.3655723251244669,
#   0.47161707234795724,
#   0.5132748027150582],
#  [0.47996699000948406,
#   0.46316338154467573,
#   0.44516790676094903,
#   0.49607239172700823,
#   0.5723856862008566],
#  [0.4142120248381562,
#   0.40717785568772896,
#   0.44556596966446943,
#   0.43296027914522833,
#   0.6001056426830921],
#  [0.4713206489138424,
#   0.42335560893738927,
#   0.4489978643190553,
#   0.48672238824854014,
#   0.495193952001081],
#  [0.48900847622170923,
#   0.4769450040083024,
#   0.449210940184263,
#   0.48058191005693857,
#   0.470559269186066]]

# %%
def powerset(s):
    x = len(s)
    ls = []
    for i in range(1 << x):
        ls.append([s[j] for j in range(x) if (i & (1 << j))])
    return ls[1:]

models = powerset(scoreSys)

def myFunc(e):
  return len(e)

models.sort(key=myFunc)

models_list = []
for i in range(len(models)):
  if len(models[i]) == 1:
    models_list.append(models[i][0])
  elif len(models[i]) == 2:
    models_list.append(models[i][0]+'&'+models[i][1])
  elif len(models[i]) == 3:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2])
  elif len(models[i]) == 4:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3])
  elif len(models[i]) == 5:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3]+'&'+models[i][4])

# %% [markdown]
# # Perform average score combinations

# %%
avg_score_combine_seed1 = pd.DataFrame({'xgb':predictions_test_xgb[0], 'rf':predictions_test_rf[0], 'svm':predictions_test_svm[0], 'adb':predictions_test_adb[0], 'cnn':predictions_test_cnn[0]})
avg_score_combine_seed2 = pd.DataFrame({'xgb':predictions_test_xgb[1], 'rf':predictions_test_rf[1], 'svm':predictions_test_svm[1], 'adb':predictions_test_adb[1], 'cnn':predictions_test_cnn[1]})
avg_score_combine_seed3 = pd.DataFrame({'xgb':predictions_test_xgb[2], 'rf':predictions_test_rf[2], 'svm':predictions_test_svm[2], 'adb':predictions_test_adb[2], 'cnn':predictions_test_cnn[2]})
avg_score_combine_seed4 = pd.DataFrame({'xgb':predictions_test_xgb[3], 'rf':predictions_test_rf[3], 'svm':predictions_test_svm[3], 'adb':predictions_test_adb[3], 'cnn':predictions_test_cnn[3]})
avg_score_combine_seed5 = pd.DataFrame({'xgb':predictions_test_xgb[4], 'rf':predictions_test_rf[4], 'svm':predictions_test_svm[4], 'adb':predictions_test_adb[4], 'cnn':predictions_test_cnn[4]})

# %%
def avg_score_combine(models_list, single_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]+single_score[j.split('&')[4]]) / 5

# %%
avg_score_combine(models_list, avg_score_combine_seed1)
avg_score_combine(models_list, avg_score_combine_seed2)
avg_score_combine(models_list, avg_score_combine_seed3)
avg_score_combine(models_list, avg_score_combine_seed4)
avg_score_combine(models_list, avg_score_combine_seed5)

# %% [markdown]
# # Perform average rank combinations

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
avg_rank_combine_seed1 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[0]), 'rf':score_to_rank(predictions_test_rf[0]), 'svm':score_to_rank(predictions_test_svm[0]), 'adb':score_to_rank(predictions_test_adb[0]), 'cnn':score_to_rank(predictions_test_cnn[0])})
avg_rank_combine_seed2 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[1]), 'rf':score_to_rank(predictions_test_rf[1]), 'svm':score_to_rank(predictions_test_svm[1]), 'adb':score_to_rank(predictions_test_adb[1]), 'cnn':score_to_rank(predictions_test_cnn[1])})
avg_rank_combine_seed3 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[2]), 'rf':score_to_rank(predictions_test_rf[2]), 'svm':score_to_rank(predictions_test_svm[2]), 'adb':score_to_rank(predictions_test_adb[2]), 'cnn':score_to_rank(predictions_test_cnn[2])})
avg_rank_combine_seed4 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[3]), 'rf':score_to_rank(predictions_test_rf[3]), 'svm':score_to_rank(predictions_test_svm[3]), 'adb':score_to_rank(predictions_test_adb[3]), 'cnn':score_to_rank(predictions_test_cnn[3])})
avg_rank_combine_seed5 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[4]), 'rf':score_to_rank(predictions_test_rf[4]), 'svm':score_to_rank(predictions_test_svm[4]), 'adb':score_to_rank(predictions_test_adb[4]), 'cnn':score_to_rank(predictions_test_cnn[4])})

# %%
def avg_rank_combine(models_list, single_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]+single_rank[j.split('&')[4]]) / 5

# %%
avg_rank_combine(models_list, avg_rank_combine_seed1)
avg_rank_combine(models_list, avg_rank_combine_seed2)
avg_rank_combine(models_list, avg_rank_combine_seed3)
avg_rank_combine(models_list, avg_rank_combine_seed4)
avg_rank_combine(models_list, avg_rank_combine_seed5)

# %% [markdown]
# # Perform weighted score combination by diversity strength

# %%
ds_score_combine_seed1 = pd.DataFrame()
ds_score_combine_seed2 = pd.DataFrame()
ds_score_combine_seed3 = pd.DataFrame()
ds_score_combine_seed4 = pd.DataFrame()
ds_score_combine_seed5 = pd.DataFrame()

# %%
def ds_score_combine(models_list, single_score, ds_score_combine, ds_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])]+single_score[j.split('&')[4]]*ds_score[scoreSys.index(j.split('&')[4])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])] + ds_score[scoreSys.index(j.split('&')[4])])

# %%
ds_score_combine(models_list, avg_score_combine_seed1, ds_score_combine_seed1, ds_score[0])
ds_score_combine(models_list, avg_score_combine_seed2, ds_score_combine_seed2, ds_score[1])
ds_score_combine(models_list, avg_score_combine_seed3, ds_score_combine_seed3, ds_score[2])
ds_score_combine(models_list, avg_score_combine_seed4, ds_score_combine_seed4, ds_score[3])
ds_score_combine(models_list, avg_score_combine_seed5, ds_score_combine_seed5, ds_score[4])

# %% [markdown]
# # Perform weighted rank combination by diversity strength

# %%
ds_rank_combine_seed1 = pd.DataFrame()
ds_rank_combine_seed2 = pd.DataFrame()
ds_rank_combine_seed3 = pd.DataFrame()
ds_rank_combine_seed4 = pd.DataFrame()
ds_rank_combine_seed5 = pd.DataFrame()

# %%
def ds_rank_combine(models_list, single_rank, ds_rank_combine, ds_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])]+single_rank[j.split('&')[4]]*ds_rank[scoreSys.index(j.split('&')[4])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])] + ds_rank[scoreSys.index(j.split('&')[4])])

# %%
ds_rank_combine(models_list, avg_rank_combine_seed1, ds_rank_combine_seed1, ds_rank[0])
ds_rank_combine(models_list, avg_rank_combine_seed2, ds_rank_combine_seed2, ds_rank[1])
ds_rank_combine(models_list, avg_rank_combine_seed3, ds_rank_combine_seed3, ds_rank[2])
ds_rank_combine(models_list, avg_rank_combine_seed4, ds_rank_combine_seed4, ds_rank[3])
ds_rank_combine(models_list, avg_rank_combine_seed5, ds_rank_combine_seed5, ds_rank[4])

# %% [markdown]
# # Perform weighted score combination by performance strength (MAE)

# %%
ps_score_combine_seed1 = pd.DataFrame()
ps_score_combine_seed2 = pd.DataFrame()
ps_score_combine_seed3 = pd.DataFrame()
ps_score_combine_seed4 = pd.DataFrame()
ps_score_combine_seed5 = pd.DataFrame()

# %%
def ps_score_combine(models_list, single_score, ps_score_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])])+single_score[j.split('&')[4]]*(1 / ps_score[scoreSys.index(j.split('&')[4])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + 1 / ps_score[scoreSys.index(j.split('&')[3])] + 1 / ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_score_combine(models_list, avg_score_combine_seed1, ps_score_combine_seed1, ps_score[0])
ps_score_combine(models_list, avg_score_combine_seed2, ps_score_combine_seed2, ps_score[1])
ps_score_combine(models_list, avg_score_combine_seed3, ps_score_combine_seed3, ps_score[2])
ps_score_combine(models_list, avg_score_combine_seed4, ps_score_combine_seed4, ps_score[3])
ps_score_combine(models_list, avg_score_combine_seed5, ps_score_combine_seed5, ps_score[4])

# %% [markdown]
# # Perform weighted rank combination by performance strength

# %%
ps_rank_combine_seed1 = pd.DataFrame()
ps_rank_combine_seed2 = pd.DataFrame()
ps_rank_combine_seed3 = pd.DataFrame()
ps_rank_combine_seed4 = pd.DataFrame()
ps_rank_combine_seed5 = pd.DataFrame()

# %%
def ps_rank_combine(models_list, single_rank, ps_rank_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])])+single_rank[j.split('&')[4]]*(ps_score[scoreSys.index(j.split('&')[4])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])] + ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_rank_combine(models_list, avg_rank_combine_seed1, ps_rank_combine_seed1, ps_score[0])
ps_rank_combine(models_list, avg_rank_combine_seed2, ps_rank_combine_seed2, ps_score[1])
ps_rank_combine(models_list, avg_rank_combine_seed3, ps_rank_combine_seed3, ps_score[2])
ps_rank_combine(models_list, avg_rank_combine_seed4, ps_rank_combine_seed4, ps_score[3])
ps_rank_combine(models_list, avg_rank_combine_seed5, ps_rank_combine_seed5, ps_score[4])

# %%
avg_rank_combine_seed1.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed2.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed3.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed4.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed5.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)

# %% [markdown]
# # Calculate MAE

# %%
score_combine_list = np.hstack((np.array(avg_score_combine_seed1.columns), np.array(ds_score_combine_seed1.columns), np.array(ps_score_combine_seed1.columns)))
MAE = pd.DataFrame(index = score_combine_list)
for i in range(1, 6):
  mae_avg, mae_ds, mae_ps = [], [], []
  for col in globals()['avg_score_combine_seed%s' %i].columns:
    mae = mean_absolute_error(np.array(globals()['avg_score_combine_seed%s' %i][col]), y_test)
    mae_avg.append(mae)
  for col in globals()['ds_score_combine_seed%s' %i].columns:
    mae = mean_absolute_error(np.array(globals()['ds_score_combine_seed%s' %i][col]), y_test)
    mae_ds.append(mae)
  for col in globals()['ps_score_combine_seed%s' %i].columns:
    mae = mean_absolute_error(np.array(globals()['ps_score_combine_seed%s' %i][col]), y_test)
    mae_ps.append(mae)
  MAE['seed'+str(i)] = np.hstack((mae_avg, mae_ds, mae_ps))

# %%
pd.set_option('display.max_rows', None)

# %%
MAE['avg_MAE'] = MAE.mean(axis=1)

# %%
MAE.sort_values(by='avg_MAE')
# Out:
#                           seed1     seed2     seed3     seed4     seed5  \
# svm                    0.393778  0.407165  0.468953  0.394654  0.422848
# rf&svm_ds              0.402138  0.408012  0.464771  0.398089  0.419785
# rf&svm_ps              0.402899  0.415927  0.465467  0.402021  0.423598
# rf&svm                 0.406095  0.416399  0.465131  0.401474  0.424256
# svm&adb_ps             0.406037  0.437525  0.463050  0.414871  0.447841
# xgb&svm_ds             0.411332  0.422626  0.478912  0.421010  0.437616
# xgb&rf&svm_ds          0.417877  0.424723  0.476215  0.420978  0.435924
# rf&svm&adb_ps          0.413202  0.437050  0.464477  0.415565  0.445439
# svm&adb                0.410492  0.439948  0.462837  0.416517  0.449364
# rf&svm&adb             0.417492  0.438830  0.464225  0.416520  0.446675
# xgb&rf&svm_ps          0.422275  0.434354  0.480143  0.430759  0.447861
# xgb&svm_ps             0.417496  0.434000  0.482606  0.433827  0.451005
# xgb&rf&svm             0.424163  0.435485  0.479268  0.431981  0.449337
# rf&svm&adb_ds          0.431420  0.448454  0.468524  0.429323  0.443071
# xgb&svm                0.418811  0.435718  0.481643  0.435390  0.453357
# svm&adb_ds             0.431441  0.452040  0.469749  0.432567  0.445164
# xgb&rf&svm&adb         0.429746  0.447054  0.476041  0.437087  0.460811
# xgb&svm&adb_ps         0.424473  0.447984  0.478335  0.440334  0.463190
# xgb&rf&svm&adb_ds      0.437069  0.452020  0.475420  0.438335  0.452663
# xgb&svm&adb            0.427803  0.450098  0.477401  0.441791  0.465230
# xgb&svm&adb_ds         0.437577  0.454293  0.477247  0.441785  0.453797
# rf                     0.445907  0.450019  0.485647  0.433317  0.455142
# rf&adb_ps              0.452390  0.465570  0.481527  0.445300  0.477331
# rf&adb                 0.452817  0.466386  0.481790  0.446574  0.477442
# xgb&rf&svm&adb&cnn_ps  0.435481  0.460271  0.512551  0.470861  0.474339
# rf&adb_ds              0.461728  0.482833  0.485940  0.458851  0.488414
# rf&svm&adb&cnn_ds      0.445562  0.460795  0.534302  0.478247  0.461678
# xgb&rf&svm&adb&cnn_ds  0.445845  0.461776  0.529634  0.478406  0.465043
# xgb&rf&svm&adb&cnn     0.439962  0.464400  0.526230  0.474988  0.475206
# xgb&rf&adb_ps          0.459458  0.472188  0.496213  0.465659  0.487753
# rf&svm&adb&cnn         0.438576  0.464318  0.533807  0.474960  0.470410
# xgb&rf&adb             0.458794  0.472696  0.496177  0.467009  0.487983
# xgb&rf_ps              0.459032  0.467849  0.504988  0.468786  0.484496
# xgb&rf_ds              0.457106  0.469562  0.502874  0.468530  0.488196
# xgb&rf                 0.457818  0.468270  0.505203  0.471121  0.484945
# rf&svm&cnn_ps          0.440110  0.456400  0.539756  0.483316  0.476163
# xgb&rf&adb_ds          0.462378  0.481097  0.492995  0.466069  0.493385
# xgb&rf&svm&cnn         0.445128  0.463253  0.544212  0.484545  0.477156
# xgb&svm&adb&cnn_ds     0.450147  0.464989  0.542507  0.489685  0.470287
# svm&adb&cnn_ds         0.451531  0.466305  0.550723  0.491195  0.468183
# svm&adb&cnn_ps         0.439448  0.473061  0.539140  0.498292  0.487308
# xgb&svm&adb&cnn        0.446015  0.472140  0.543173  0.492985  0.486128
# rf&svm&cnn             0.449840  0.465971  0.562371  0.492136  0.477031
# xgb&adb_ds             0.469226  0.491294  0.501489  0.478162  0.507984
# adb                    0.470516  0.498025  0.496489  0.474317  0.509675
# xgb&rf&svm&cnn_ds      0.466122  0.453339  0.566205  0.502915  0.463897
# xgb&adb                0.470931  0.489684  0.508779  0.487435  0.507975
# xgb&adb_ps             0.471416  0.489782  0.509185  0.487813  0.507942
# xgb&svm&cnn_ps         0.448987  0.468221  0.553204  0.510574  0.494377
# svm&adb&cnn            0.448144  0.481280  0.560522  0.502814  0.488426
# rf&adb&cnn_ps          0.456649  0.485166  0.540476  0.503719  0.499431
# xgb&rf&adb&cnn         0.457834  0.483119  0.546710  0.502794  0.497901
# rf&svm&cnn_ds          0.478664  0.455030  0.585447  0.513488  0.464008
# xgb&rf&adb&cnn_ds      0.460222  0.484827  0.547012  0.504824  0.500001
# rf&adb&cnn_ds          0.462088  0.487362  0.555870  0.508621  0.499709
# rf&adb&cnn             0.459477  0.490204  0.562634  0.509988  0.498922
# xgb&svm&cnn            0.460028  0.476685  0.573858  0.515808  0.495542
# xgb&rf&cnn_ps          0.464790  0.483564  0.555261  0.516476  0.506948
# xgb&svm&cnn_ds         0.487409  0.461995  0.601056  0.533801  0.474760
# xgb&rf&cnn             0.468249  0.489074  0.575704  0.522825  0.506395
# xgb                    0.480440  0.502051  0.535858  0.518432  0.525516
# xgb&adb&cnn_ds         0.467787  0.493184  0.567264  0.524118  0.513561
# xgb&adb&cnn_ps         0.467289  0.496380  0.557079  0.534991  0.519977
# xgb&adb&cnn            0.470592  0.499838  0.576304  0.536316  0.519448
# adb&cnn_ds             0.472243  0.499271  0.583542  0.532248  0.519724
# rf&cnn_ps              0.479206  0.498858  0.586548  0.535541  0.523061
# svm&cnn_ps             0.469586  0.492491  0.601848  0.549472  0.520126
# xgb&rf&cnn_ds          0.496129  0.495060  0.605347  0.555147  0.513582
# rf&cnn                 0.485589  0.508439  0.617972  0.548919  0.522241
# svm&cnn_ds             0.516050  0.476364  0.653228  0.570069  0.481888
# adb&cnn_ps             0.483965  0.521597  0.592970  0.568218  0.537735
# svm&cnn                0.487423  0.508540  0.628804  0.559222  0.523243
# adb&cnn                0.487077  0.527966  0.619235  0.569464  0.536801
# xgb&cnn_ps             0.491693  0.517514  0.610405  0.585380  0.553982
# xgb&cnn                0.501981  0.524097  0.637665  0.588654  0.552351
# rf&cnn_ds              0.524951  0.519531  0.647080  0.593801  0.538029
# xgb&cnn_ds             0.538979  0.528576  0.680028  0.632457  0.555718
# cnn                    0.627091  0.664098  0.840857  0.768529  0.677255
# xgb&rf&svm&cnn_ps      0.852704  0.744917  0.672628  0.962500  1.002467
# xgb&rf&adb&cnn_ps      0.896809  0.762208  0.670582  0.976847  1.010365
# rf&svm&adb&cnn_ps      0.913710  0.763610  0.681292  0.977370  1.025573
# xgb&svm&adb&cnn_ps     0.868106  0.772868  0.700216  1.014430  1.021132
# xgb&rf&svm&adb_ps      0.949146  0.965126  1.071378  0.993194  1.041401
#
#                         avg_MAE
# svm                    0.417480
# rf&svm_ds              0.418559
# rf&svm_ps              0.421983
# rf&svm                 0.422671
# svm&adb_ps             0.433865
# xgb&svm_ds             0.434299
# xgb&rf&svm_ds          0.435143
# rf&svm&adb_ps          0.435146
# svm&adb                0.435832
# rf&svm&adb             0.436748
# xgb&rf&svm_ps          0.443079
# xgb&svm_ps             0.443787
# xgb&rf&svm             0.444047
# rf&svm&adb_ds          0.444158
# xgb&svm                0.444984
# svm&adb_ds             0.446192
# xgb&rf&svm&adb         0.450148
# xgb&svm&adb_ps         0.450863
# xgb&rf&svm&adb_ds      0.451101
# xgb&svm&adb            0.452465
# xgb&svm&adb_ds         0.452940
# rf                     0.454006
# rf&adb_ps              0.464424
# rf&adb                 0.465002
# xgb&rf&svm&adb&cnn_ps  0.470700
# rf&adb_ds              0.475553
# rf&svm&adb&cnn_ds      0.476117
# xgb&rf&svm&adb&cnn_ds  0.476141
# xgb&rf&svm&adb&cnn     0.476157
# xgb&rf&adb_ps          0.476254
# rf&svm&adb&cnn         0.476414
# xgb&rf&adb             0.476532
# xgb&rf_ps              0.477030
# xgb&rf_ds              0.477254
# xgb&rf                 0.477471
# rf&svm&cnn_ps          0.479149
# xgb&rf&adb_ds          0.479185
# xgb&rf&svm&cnn         0.482859
# xgb&svm&adb&cnn_ds     0.483523
# svm&adb&cnn_ds         0.485587
# svm&adb&cnn_ps         0.487450
# xgb&svm&adb&cnn        0.488088
# rf&svm&cnn             0.489470
# xgb&adb_ds             0.489631
# adb                    0.489804
# xgb&rf&svm&cnn_ds      0.490496
# xgb&adb                0.492961
# xgb&adb_ps             0.493228
# xgb&svm&cnn_ps         0.495073
# svm&adb&cnn            0.496237
# rf&adb&cnn_ps          0.497088
# xgb&rf&adb&cnn         0.497672
# rf&svm&cnn_ds          0.499327
# xgb&rf&adb&cnn_ds      0.499377
# rf&adb&cnn_ds          0.502730
# rf&adb&cnn             0.504245
# xgb&svm&cnn            0.504384
# xgb&rf&cnn_ps          0.505408
# xgb&svm&cnn_ds         0.511804
# xgb&rf&cnn             0.512449
# xgb                    0.512460
# xgb&adb&cnn_ds         0.513183
# xgb&adb&cnn_ps         0.515143
# xgb&adb&cnn            0.520499
# adb&cnn_ds             0.521406
# rf&cnn_ps              0.524642
# svm&cnn_ps             0.526705
# xgb&rf&cnn_ds          0.533053
# rf&cnn                 0.536632
# svm&cnn_ds             0.539520
# adb&cnn_ps             0.540897
# svm&cnn                0.541447
# adb&cnn                0.548109
# xgb&cnn_ps             0.551795
# xgb&cnn                0.560950
# rf&cnn_ds              0.564678
# xgb&cnn_ds             0.587152
# cnn                    0.715566
# xgb&rf&svm&cnn_ps      0.847043
# xgb&rf&adb&cnn_ps      0.863362
# rf&svm&adb&cnn_ps      0.872311
# xgb&svm&adb&cnn_ps     0.875350
# xgb&rf&svm&adb_ps      1.004049
