# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm #progress bar
import rdkit
from rdkit import Chem #Chemistry
from rdkit.Chem import rdMolDescriptors #molecular descriptors
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
rdkit.__version__

import xgboost as xgb
import sklearn
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import fbeta_score, make_scorer
from xgboost.sklearn import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split #ML training
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error #ML stats
from tdc.single_pred import ADME
from tdc.benchmark_group import admet_group
from tdc import BenchmarkGroup
import warnings
warnings.filterwarnings("ignore")

# %%
group = admet_group(path = 'data/')

pred_valid_list_xgb = []
pred_valid_list_rf = []
pred_valid_list_svm = []
pred_valid_list_adb = []
pred_valid_list_cnn = []
        
pred_test_list_xgb = []
pred_test_list_rf = []
pred_test_list_svm = []
pred_test_list_adb = []
pred_test_list_cnn = []

best_params_list_xgb = []
best_params_list_svm = []

for seed in [1, 2, 3, 4, 5]:
    pred_valid_xgb = {}
    pred_valid_rf = {}
    pred_valid_svm = {}
    pred_valid_adb = {}
    pred_valid_cnn = {}

    pred_test_xgb = {}
    pred_test_rf = {}
    pred_test_svm = {}
    pred_test_adb = {}
    pred_test_cnn = {}

    benchmark = group.get('VDss_Lombardo')
    name = benchmark['name']
    train_val, test = benchmark['train_val'], benchmark['test']
    train, valid = group.get_train_valid_split(benchmark = name, split_type = 'default', seed = seed)

    PandasTools.AddMoleculeColumnToFrame(train, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in train['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = train['Y']
    train = pd.DataFrame(ecfp6_bits, index = train.Drug, columns=ecfp6_name).reset_index(drop = False)
    train['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(valid, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in valid['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = valid['Y']
    valid = pd.DataFrame(ecfp6_bits, index = valid.Drug, columns=ecfp6_name).reset_index(drop = False)
    valid['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(benchmark['test'], smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in benchmark['test']['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = benchmark['test']['Y']
    benchmark['test'] = pd.DataFrame(ecfp6_bits, index = benchmark['test'].Drug, columns=ecfp6_name).reset_index(drop = False)
    benchmark['test']['Y'] = Y

    train_X = train.drop(columns = ["Drug","Y"])
    train_y = train.Y
    valid_X = valid.drop(columns = ["Drug","Y"])
    globals()['valid_y_%s'%seed] = valid.Y
    test_X = benchmark['test'].drop(columns = ["Drug","Y"])
    test_y = benchmark['test'].Y

    
    #XGBoost + Morgan
    xgb_parameters = {'objective':['reg:squarederror'],
            'booster':['gbtree','gblinear'],
            'learning_rate': [0.1],
            'max_depth': [7,10,15,20],
            'min_child_weight': [10,15,20,25],
            'colsample_bytree': [0.8, 0.9, 1],
            'n_estimators': [300,400,500,600],
            "reg_alpha"   : [0.5,0.2,1],
            "reg_lambda"  : [2,3,5],
            "gamma"       : [1,2,3]}

    xgb_model = XGBRegressor()
    grid_obj_xgb = RandomizedSearchCV(xgb_model, xgb_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_xgb.fit(train_X, train_y, verbose = 1)
    y_pred_valid_xgb = grid_obj_xgb.predict(valid_X)
    y_pred_test_xgb = grid_obj_xgb.predict(test_X)
    pred_valid_xgb[name] = y_pred_valid_xgb
    pred_valid_list_xgb.append(pred_valid_xgb)
    pred_test_xgb[name] = y_pred_test_xgb
    pred_test_list_xgb.append(pred_test_xgb)
    bp_xgb = grid_obj_xgb.best_params_
    best_params_list_xgb.append(bp_xgb)

    #Random Forest + Morgan
    rf_model = RandomForestRegressor()
    rf_model.fit(train_X, train_y)
    y_pred_valid_rf = rf_model.predict(valid_X)
    y_pred_test_rf = rf_model.predict(test_X)
    pred_valid_rf[name] = y_pred_valid_rf
    pred_valid_list_rf.append(pred_valid_rf)
    pred_test_rf[name] = y_pred_test_rf
    pred_test_list_rf.append(pred_test_rf)

    #SVM + Morgan
    svm_parameters = {
        'C': [0.1, 1, 10, 100, 1000],
        'epsilon': [0.0001, 0.001, 0.01, 0.1, 0.5],
        'gamma': [0.0001, 0.001, 0.01, 0.1, 1]
    }
    svm_model = SVR(kernel="rbf")
    grid_obj_svm = RandomizedSearchCV(svm_model, svm_parameters, cv=5, n_iter=15, scoring='neg_mean_absolute_error', verbose=5, n_jobs=1)
    grid_obj_svm.fit(train_X, train_y)
    y_pred_valid_svm = grid_obj_svm.predict(valid_X)
    y_pred_test_svm = grid_obj_svm.predict(test_X)
    pred_valid_svm[name] = y_pred_valid_svm
    pred_valid_list_svm.append(pred_valid_svm)
    pred_test_svm[name] = y_pred_test_svm
    pred_test_list_svm.append(pred_test_svm)
    bp_svm = grid_obj_svm.best_params_
    best_params_list_svm.append(bp_svm)
    
    # AdaBoost + Morgan
    DTR = DecisionTreeRegressor(max_depth=4)
    adb_model = AdaBoostRegressor(n_estimators=300, base_estimator=DTR, learning_rate=1)
    adb_model.fit(train_X, train_y)
    y_pred_valid_adb = adb_model.predict(valid_X)
    y_pred_test_adb = adb_model.predict(test_X)
    pred_valid_adb[name] = y_pred_valid_adb
    pred_valid_list_adb.append(pred_valid_adb)
    pred_test_adb[name] = y_pred_test_adb
    pred_test_list_adb.append(pred_test_adb)

    #CNN + Morgan
    train_X_cnn = train_X.to_numpy()
    valid_X_cnn = valid_X.to_numpy()
    test_X_cnn = test_X.to_numpy()
    train_X_cnn = train_X_cnn.reshape(train_X_cnn.shape[0], train_X_cnn.shape[1], 1)
    valid_X_cnn = valid_X_cnn.reshape(valid_X_cnn.shape[0], valid_X_cnn.shape[1], 1)
    test_X_cnn = test_X_cnn.reshape(test_X_cnn.shape[0], test_X_cnn.shape[1], 1)
    cnn_model = Sequential()
    cnn_model.add(Conv1D(32, 2, activation="relu", input_shape=(1024,1)))
    cnn_model.add(Flatten())
    cnn_model.add(Dense(64, activation="relu"))
    cnn_model.add(Dense(1))
    cnn_model.compile(loss="CosineSimilarity", optimizer="adam")
    cnn_model.fit(train_X_cnn, train_y, batch_size=12, epochs=10, verbose=0)
    y_pred_valid_cnn = cnn_model.predict(valid_X_cnn)
    y_pred_test_cnn = cnn_model.predict(test_X_cnn)
    y_pred_valid_cnn_copy = []
    for i in range(len(y_pred_valid_cnn)):
        y_pred_valid_cnn_copy.append(y_pred_valid_cnn[i][0])
    y_pred_test_cnn_copy = []
    for i in range(len(y_pred_test_cnn)):
        y_pred_test_cnn_copy.append(y_pred_test_cnn[i][0])
    pred_valid_cnn[name] = np.array(y_pred_valid_cnn_copy)
    pred_valid_list_cnn.append(pred_valid_cnn)
    pred_test_cnn[name] = np.array(y_pred_test_cnn_copy)
    pred_test_list_cnn.append(pred_test_cnn)


xgb_perform = group.evaluate_many(pred_test_list_xgb)
rf_perform = group.evaluate_many(pred_test_list_rf)
svm_perform = group.evaluate_many(pred_test_list_svm)
adb_perform = group.evaluate_many(pred_test_list_adb)
cnn_perform = group.evaluate_many(pred_test_list_cnn)
# Out:
# Found local copy...
# generating training, validation splits...
# 100%|██████████| 904/904 [00:00<00:00, 1564.06it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [03:33:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.393 total time=   1.9s
# [03:33:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-3.902 total time=   1.9s
# [03:33:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.855 total time=   1.8s
# [03:33:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.894 total time=   1.9s
# [03:33:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-3.717 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-5.745 total time=   8.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.420 total time=   7.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-6.669 total time=   7.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-8.814 total time=   6.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.128 total time=  10.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-6.122 total time=  10.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-6.397 total time=  12.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.247 total time=  10.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-9.031 total time=  11.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-4.631 total time=  11.3s
# [03:35:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-4.357 total time=   2.3s
# [03:35:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-3.680 total time=   2.5s
# [03:35:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-4.745 total time=   2.9s
# [03:35:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.843 total time=   2.0s
# [03:35:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-3.852 total time=   2.0s
# [03:35:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.402 total time=   1.9s
# [03:35:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-3.976 total time=   1.9s
# [03:35:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.890 total time=   2.1s
# [03:35:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.905 total time=   2.3s
# [03:35:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-3.680 total time=   2.2s
# [03:35:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-4.357 total time=   2.2s
# [03:35:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-3.680 total time=   2.0s
# [03:35:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-4.745 total time=   2.4s
# [03:35:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.843 total time=   2.3s
# [03:35:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-3.852 total time=   2.4s
# [03:35:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-4.389 total time=   1.3s
# [03:35:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-3.941 total time=   1.3s
# [03:35:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-4.874 total time=   1.5s
# [03:35:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-8.905 total time=   1.4s
# [03:35:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-3.659 total time=   1.7s
# [03:35:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-4.344 total time=   1.6s
# [03:35:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-3.727 total time=   1.5s
# [03:35:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-4.784 total time=   1.3s
# [03:35:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.879 total time=   1.4s
# [03:35:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-3.695 total time=   1.3s
# [03:35:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.385 total time=   1.7s
# [03:35:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-3.809 total time=   1.7s
# [03:35:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.803 total time=   1.7s
# [03:35:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-8.866 total time=   1.8s
# [03:35:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-3.812 total time=   1.7s
# [03:35:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.393 total time=   1.9s
# [03:36:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-3.902 total time=   1.9s
# [03:36:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.855 total time=   2.0s
# [03:36:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.894 total time=   1.9s
# [03:36:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-3.717 total time=   2.0s
# [03:36:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.402 total time=   1.7s
# [03:36:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-3.976 total time=   1.7s
# [03:36:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.890 total time=   2.7s
# [03:36:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.905 total time=   2.2s
# [03:36:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-3.680 total time=   2.0s
# [03:36:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-4.414 total time=   1.8s
# [03:36:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-4.007 total time=   2.0s
# [03:36:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-4.905 total time=   2.1s
# [03:36:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.905 total time=   1.5s
# [03:36:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-3.698 total time=   1.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.278 total time=   5.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.749 total time=   5.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-6.261 total time=   6.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.946 total time=   6.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.160 total time=   6.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-5.588 total time=  10.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.576 total time=  11.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-7.390 total time=  14.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-8.925 total time=  13.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-3.905 total time=  14.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.554 total time=   8.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-6.133 total time=   9.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-6.258 total time=   7.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.855 total time=   7.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.421 total time=   8.4s
# [03:38:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ....C=1, epsilon=0.001, gamma=0.1;, score=-3.090 total time=   0.2s
# [CV 2/5] END ....C=1, epsilon=0.001, gamma=0.1;, score=-2.704 total time=   0.2s
# [CV 3/5] END ....C=1, epsilon=0.001, gamma=0.1;, score=-3.652 total time=   0.2s
# [CV 4/5] END ....C=1, epsilon=0.001, gamma=0.1;, score=-7.827 total time=   0.2s
# [CV 5/5] END ....C=1, epsilon=0.001, gamma=0.1;, score=-1.786 total time=   0.2s
# [CV 1/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-3.267 total time=   0.2s
# [CV 2/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-2.622 total time=   0.2s
# [CV 3/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-3.693 total time=   0.2s
# [CV 4/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-8.303 total time=   0.2s
# [CV 5/5] END C=100, epsilon=0.0001, gamma=0.001;, score=-1.971 total time=   0.2s
# [CV 1/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-3.135 total time=   0.1s
# [CV 2/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-2.782 total time=   0.2s
# [CV 3/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-3.714 total time=   0.1s
# [CV 4/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-7.824 total time=   0.1s
# [CV 5/5] END .C=0.1, epsilon=0.0001, gamma=0.1;, score=-1.861 total time=   0.2s
# [CV 1/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-3.140 total time=   0.2s
# [CV 2/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-2.791 total time=   0.2s
# [CV 3/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-3.721 total time=   0.2s
# [CV 4/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-7.837 total time=   0.1s
# [CV 5/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-1.870 total time=   0.1s
# [CV 1/5] END ...C=1, epsilon=0.5, gamma=0.0001;, score=-3.119 total time=   0.1s
# [CV 2/5] END ...C=1, epsilon=0.5, gamma=0.0001;, score=-2.759 total time=   0.1s
# [CV 3/5] END ...C=1, epsilon=0.5, gamma=0.0001;, score=-3.690 total time=   0.1s
# [CV 4/5] END ...C=1, epsilon=0.5, gamma=0.0001;, score=-7.828 total time=   0.1s
# [CV 5/5] END ...C=1, epsilon=0.5, gamma=0.0001;, score=-1.834 total time=   0.1s
# [CV 1/5] END ......C=0.1, epsilon=0.5, gamma=1;, score=-3.145 total time=   0.1s
# [CV 2/5] END ......C=0.1, epsilon=0.5, gamma=1;, score=-2.795 total time=   0.1s
# [CV 3/5] END ......C=0.1, epsilon=0.5, gamma=1;, score=-3.723 total time=   0.1s
# [CV 4/5] END ......C=0.1, epsilon=0.5, gamma=1;, score=-7.866 total time=   0.1s
# [CV 5/5] END ......C=0.1, epsilon=0.5, gamma=1;, score=-1.859 total time=   0.1s
# [CV 1/5] END ...C=1, epsilon=0.001, gamma=0.01;, score=-2.887 total time=   0.2s
# [CV 2/5] END ...C=1, epsilon=0.001, gamma=0.01;, score=-2.402 total time=   0.1s
# [CV 3/5] END ...C=1, epsilon=0.001, gamma=0.01;, score=-3.400 total time=   0.2s
# [CV 4/5] END ...C=1, epsilon=0.001, gamma=0.01;, score=-7.652 total time=   0.2s
# [CV 5/5] END ...C=1, epsilon=0.001, gamma=0.01;, score=-1.541 total time=   0.2s
# [CV 1/5] END C=0.1, epsilon=0.001, gamma=0.001;, score=-3.117 total time=   0.2s
# [CV 2/5] END C=0.1, epsilon=0.001, gamma=0.001;, score=-2.760 total time=   0.2s
# [CV 3/5] END C=0.1, epsilon=0.001, gamma=0.001;, score=-3.693 total time=   0.2s
# [CV 4/5] END C=0.1, epsilon=0.001, gamma=0.001;, score=-7.800 total time=   0.2s
# [CV 5/5] END C=0.1, epsilon=0.001, gamma=0.001;, score=-1.847 total time=   0.1s
# [CV 1/5] END ...C=1000, epsilon=0.5, gamma=0.1;, score=-4.377 total time=   0.1s
# [CV 2/5] END ...C=1000, epsilon=0.5, gamma=0.1;, score=-3.823 total time=   0.2s
# [CV 3/5] END ...C=1000, epsilon=0.5, gamma=0.1;, score=-4.856 total time=   0.2s
# [CV 4/5] END ...C=1000, epsilon=0.5, gamma=0.1;, score=-8.936 total time=   0.2s
# [CV 5/5] END ...C=1000, epsilon=0.5, gamma=0.1;, score=-3.561 total time=   0.2s
# [CV 1/5] END C=1000, epsilon=0.0001, gamma=0.1;, score=-4.168 total time=   0.2s
# [CV 2/5] END C=1000, epsilon=0.0001, gamma=0.1;, score=-3.614 total time=   0.2s
# [CV 3/5] END C=1000, epsilon=0.0001, gamma=0.1;, score=-4.660 total time=   0.2s
# [CV 4/5] END C=1000, epsilon=0.0001, gamma=0.1;, score=-8.742 total time=   0.2s
# [CV 5/5] END C=1000, epsilon=0.0001, gamma=0.1;, score=-3.302 total time=   0.2s
# [CV 1/5] END ...C=0.1, epsilon=0.01, gamma=0.1;, score=-3.135 total time=   0.2s
# [CV 2/5] END ...C=0.1, epsilon=0.01, gamma=0.1;, score=-2.782 total time=   0.2s
# [CV 3/5] END ...C=0.1, epsilon=0.01, gamma=0.1;, score=-3.714 total time=   0.2s
# [CV 4/5] END ...C=0.1, epsilon=0.01, gamma=0.1;, score=-7.824 total time=   0.1s
# [CV 5/5] END ...C=0.1, epsilon=0.01, gamma=0.1;, score=-1.862 total time=   0.2s
# [CV 1/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-3.143 total time=   0.2s
# [CV 2/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-2.795 total time=   0.2s
# [CV 3/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-3.725 total time=   0.1s
# [CV 4/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-7.833 total time=   0.1s
# [CV 5/5] END ...C=0.1, epsilon=0.0001, gamma=1;, score=-1.874 total time=   0.1s
# [CV 1/5] END ......C=1, epsilon=0.1, gamma=0.1;, score=-3.095 total time=   0.1s
# [CV 2/5] END ......C=1, epsilon=0.1, gamma=0.1;, score=-2.712 total time=   0.1s
# [CV 3/5] END ......C=1, epsilon=0.1, gamma=0.1;, score=-3.659 total time=   0.2s
# [CV 4/5] END ......C=1, epsilon=0.1, gamma=0.1;, score=-7.846 total time=   0.1s
# [CV 5/5] END ......C=1, epsilon=0.1, gamma=0.1;, score=-1.797 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.001, gamma=0.001;, score=-4.914 total time=   0.2s
# [CV 2/5] END C=1000, epsilon=0.001, gamma=0.001;, score=-4.017 total time=   0.2s
# [CV 3/5] END C=1000, epsilon=0.001, gamma=0.001;, score=-5.026 total time=   0.2s
# [CV 4/5] END C=1000, epsilon=0.001, gamma=0.001;, score=-10.099 total time=   0.2s
# [CV 5/5] END C=1000, epsilon=0.001, gamma=0.001;, score=-4.080 total time=   0.2s
# [CV 1/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-4.005 total time=   0.1s
# [CV 2/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-2.972 total time=   0.1s
# [CV 3/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-4.149 total time=   0.1s
# [CV 4/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-9.005 total time=   0.1s
# [CV 5/5] END ...C=100, epsilon=0.5, gamma=0.01;, score=-3.160 total time=   0.1s
# 4/4 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# generating training, validation splits...
# 100%|██████████| 904/904 [00:00<00:00, 1697.26it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [03:39:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-5.076 total time=   0.9s
# [03:39:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-5.564 total time=   0.9s
# [03:39:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-3.833 total time=   0.9s
# [03:39:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-9.915 total time=   1.0s
# [03:39:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.409 total time=   1.1s
# [03:39:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.028 total time=   1.5s
# [03:39:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.503 total time=   1.5s
# [03:39:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-3.772 total time=   1.4s
# [03:39:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-9.931 total time=   1.4s
# [03:39:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-4.326 total time=   1.3s
# [03:39:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.875 total time=   1.4s
# [03:39:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-5.411 total time=   1.4s
# [03:39:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-3.606 total time=   1.5s
# [03:39:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-9.869 total time=   1.5s
# [03:39:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.475 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-5.592 total time=   9.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-5.672 total time=   9.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-6.332 total time=   7.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.936 total time=   7.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-4.189 total time=   7.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-6.522 total time=  14.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-7.777 total time=  13.3s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.401 total time=  13.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-9.745 total time=  13.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.241 total time=  15.5s
# [03:41:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-5.076 total time=   1.4s
# [03:41:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-5.564 total time=   1.5s
# [03:41:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-3.833 total time=   1.5s
# [03:41:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-9.915 total time=   1.5s
# [03:41:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-4.409 total time=   1.5s
# [03:41:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-5.187 total time=   1.0s
# [03:41:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-5.610 total time=   1.0s
# [03:41:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-3.955 total time=   1.1s
# [03:41:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# ...
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-5.747 total time=   5.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=400, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-7.359 total time=   5.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-9.559 total time=   4.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-6.001 total time=   4.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.467 total time=   4.3s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.428 total time=   5.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.251 total time=   5.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-9.152 total time=   7.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.901 total time=   7.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.058 total time=   7.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.584 total time=   7.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-7.086 total time=   7.2s
# [03:58:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-9.606 total time=   1.2s
# [03:58:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-4.936 total time=   1.3s
# [03:58:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-4.689 total time=   1.3s
# [03:58:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-5.302 total time=   1.5s
# [03:58:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-4.538 total time=   1.2s
# [03:58:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-9.606 total time=   0.8s
# [03:58:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.968 total time=   0.8s
# [03:58:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.709 total time=   0.8s
# [03:58:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-5.328 total time=   0.8s
# [03:58:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=15, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-4.559 total time=   0.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-9.619 total time=   5.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-7.409 total time=   6.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.446 total time=   5.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.598 total time=   7.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-4.650 total time=   6.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-9.726 total time=   9.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-7.368 total time=   8.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.642 total time=   8.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.533 total time=   9.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-4.799 total time=   8.6s
# [03:59:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ..C=1000, epsilon=0.5, gamma=0.01;, score=-9.618 total time=   0.1s
# [CV 2/5] END ..C=1000, epsilon=0.5, gamma=0.01;, score=-4.751 total time=   0.1s
# [CV 3/5] END ..C=1000, epsilon=0.5, gamma=0.01;, score=-4.868 total time=   0.1s
# [CV 4/5] END ..C=1000, epsilon=0.5, gamma=0.01;, score=-5.086 total time=   0.1s
# [CV 5/5] END ..C=1000, epsilon=0.5, gamma=0.01;, score=-4.647 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-8.691 total time=   0.2s
# [CV 2/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-3.418 total time=   0.2s
# [CV 3/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-3.063 total time=   0.2s
# [CV 4/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-3.598 total time=   0.2s
# [CV 5/5] END C=1000, epsilon=0.01, gamma=0.0001;, score=-2.903 total time=   0.2s
# [CV 1/5] END ....C=10, epsilon=0.5, gamma=0.01;, score=-8.453 total time=   0.1s
# [CV 2/5] END ....C=10, epsilon=0.5, gamma=0.01;, score=-3.200 total time=   0.1s
# [CV 3/5] END ....C=10, epsilon=0.5, gamma=0.01;, score=-2.901 total time=   0.1s
# [CV 4/5] END ....C=10, epsilon=0.5, gamma=0.01;, score=-3.359 total time=   0.1s
# [CV 5/5] END ....C=10, epsilon=0.5, gamma=0.01;, score=-2.412 total time=   0.1s
# [CV 1/5] END ...C=100, epsilon=0.1, gamma=0.01;, score=-9.227 total time=   0.2s
# [CV 2/5] END ...C=100, epsilon=0.1, gamma=0.01;, score=-3.744 total time=   0.2s
# [CV 3/5] END ...C=100, epsilon=0.1, gamma=0.01;, score=-3.928 total time=   0.2s
# [CV 4/5] END ...C=100, epsilon=0.1, gamma=0.01;, score=-3.987 total time=   0.2s
# [CV 5/5] END ...C=100, epsilon=0.1, gamma=0.01;, score=-3.407 total time=   0.2s
# [CV 1/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-8.449 total time=   0.1s
# [CV 2/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-3.826 total time=   0.1s
# [CV 3/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-3.062 total time=   0.1s
# [CV 4/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-3.662 total time=   0.1s
# [CV 5/5] END ..C=0.1, epsilon=0.5, gamma=0.001;, score=-2.503 total time=   0.1s
# [CV 1/5] END ........C=1, epsilon=0.1, gamma=1;, score=-8.490 total time=   0.1s
# [CV 2/5] END ........C=1, epsilon=0.1, gamma=1;, score=-3.859 total time=   0.1s
# [CV 3/5] END ........C=1, epsilon=0.1, gamma=1;, score=-3.070 total time=   0.1s
# [CV 4/5] END ........C=1, epsilon=0.1, gamma=1;, score=-3.688 total time=   0.1s
# [CV 5/5] END ........C=1, epsilon=0.1, gamma=1;, score=-2.540 total time=   0.1s
# [CV 1/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-8.452 total time=   0.1s
# [CV 2/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-3.868 total time=   0.1s
# [CV 3/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-3.082 total time=   0.1s
# [CV 4/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-3.683 total time=   0.1s
# [CV 5/5] END C=0.1, epsilon=0.0001, gamma=0.0001;, score=-2.522 total time=   0.2s
# [CV 1/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-9.593 total time=   0.1s
# [CV 2/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-5.085 total time=   0.2s
# [CV 3/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-4.703 total time=   0.2s
# [CV 4/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-5.330 total time=   0.2s
# [CV 5/5] END .....C=1000, epsilon=0.1, gamma=1;, score=-4.641 total time=   0.2s
# [CV 1/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-8.392 total time=   0.1s
# [CV 2/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-3.726 total time=   0.1s
# [CV 3/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-2.991 total time=   0.1s
# [CV 4/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-3.580 total time=   0.1s
# [CV 5/5] END ...C=0.1, epsilon=0.5, gamma=0.01;, score=-2.426 total time=   0.1s
# [CV 1/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-8.310 total time=   0.1s
# [CV 2/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-3.636 total time=   0.1s
# [CV 3/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-2.925 total time=   0.1s
# [CV 4/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-3.481 total time=   0.1s
# [CV 5/5] END .C=10, epsilon=0.01, gamma=0.0001;, score=-2.354 total time=   0.1s
# [CV 1/5] END ..C=0.1, epsilon=0.01, gamma=0.01;, score=-8.352 total time=   0.1s
# [CV 2/5] END ..C=0.1, epsilon=0.01, gamma=0.01;, score=-3.716 total time=   0.1s
# [CV 3/5] END ..C=0.1, epsilon=0.01, gamma=0.01;, score=-2.983 total time=   0.1s
# [CV 4/5] END ..C=0.1, epsilon=0.01, gamma=0.01;, score=-3.546 total time=   0.1s
# [CV 5/5] END ..C=0.1, epsilon=0.01, gamma=0.01;, score=-2.398 total time=   0.1s
# [CV 1/5] END C=1000, epsilon=0.1, gamma=0.001;, score=-10.417 total time=   0.2s
# [CV 2/5] END .C=1000, epsilon=0.1, gamma=0.001;, score=-5.104 total time=   0.2s
# [CV 3/5] END .C=1000, epsilon=0.1, gamma=0.001;, score=-5.113 total time=   0.2s
# [CV 4/5] END .C=1000, epsilon=0.1, gamma=0.001;, score=-4.858 total time=   0.2s
# [CV 5/5] END .C=1000, epsilon=0.1, gamma=0.001;, score=-4.589 total time=   0.2s
# [CV 1/5] END .....C=10, epsilon=0.5, gamma=0.1;, score=-9.061 total time=   0.2s
# [CV 2/5] END .....C=10, epsilon=0.5, gamma=0.1;, score=-3.970 total time=   0.2s
# [CV 3/5] END .....C=10, epsilon=0.5, gamma=0.1;, score=-3.405 total time=   0.1s
# [CV 4/5] END .....C=10, epsilon=0.5, gamma=0.1;, score=-4.146 total time=   0.1s
# [CV 5/5] END .....C=10, epsilon=0.5, gamma=0.1;, score=-3.111 total time=   0.1s
# [CV 1/5] END ....C=100, epsilon=0.5, gamma=0.1;, score=-9.446 total time=   0.1s
# [CV 2/5] END ....C=100, epsilon=0.5, gamma=0.1;, score=-4.252 total time=   0.1s
# [CV 3/5] END ....C=100, epsilon=0.5, gamma=0.1;, score=-3.900 total time=   0.1s
# [CV 4/5] END ....C=100, epsilon=0.5, gamma=0.1;, score=-4.615 total time=   0.1s
# [CV 5/5] END ....C=100, epsilon=0.5, gamma=0.1;, score=-3.887 total time=   0.1s
# [CV 1/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-9.267 total time=   0.2s
# [CV 2/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-4.084 total time=   0.2s
# [CV 3/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-3.701 total time=   0.2s
# [CV 4/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-4.428 total time=   0.2s
# [CV 5/5] END ..C=100, epsilon=0.001, gamma=0.1;, score=-3.665 total time=   0.2s
# 4/4 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 2ms/step

# %%
print("xgb_perform:", xgb_perform, "\n rf_perform:", rf_perform, "\n svm_perform:", svm_perform, "\n adb_perform:", adb_perform, "\n cnn_perform:", cnn_perform)
# Out:
# xgb_perform: {'vdss_lombardo': [0.348, 0.01]}
#  rf_perform: {'vdss_lombardo': [0.525, 0.012]}
#  svm_perform: {'vdss_lombardo': [0.582, 0.031]}
#  adb_perform: {'vdss_lombardo': [0.318, 0.053]}
#  cnn_perform: {'vdss_lombardo': [-0.017, 0.05]}

# %%
y_test = benchmark['test'].Y
y_test = np.array(y_test)

# %%
def rank_object(array): # convert scores into ranks
    arg_a = np.argsort(array)
    b = np.flip(np.arange(len(arg_a)))
    a = np.zeros_like(arg_a)
    for i in range(len(arg_a)):
        a[arg_a[i]] = b[i]
    return a

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
def normalize(array): # define function for normalization of scores
    maximum = np.max(array)
    minimum = np.min(array)
    norm_list = []
    for i in range(len(array)):
        norm_list.append((array[i]-minimum)/(maximum-minimum))
    return np.array(norm_list)

# %%
predictions_valid_xgb = []
predictions_valid_rf = []
predictions_valid_svm = []
predictions_valid_adb = []
predictions_valid_cnn = []

predictions_test_xgb = []
predictions_test_rf = []
predictions_test_svm = []
predictions_test_adb = []
predictions_test_cnn = []

scoreSys = ['xgb', 'rf', 'svm', 'adb', 'cnn']

for sys in scoreSys:
  for seed in range(len(globals()['pred_valid_list_%s' % sys])):
    globals()['predictions_valid_%s' % sys].append(list(globals()['pred_valid_list_%s' % sys][seed].values())[0])

for sys in scoreSys:
  for seed in range(len(globals()['pred_test_list_%s' % sys])):
    globals()['predictions_test_%s' % sys].append(list(globals()['pred_test_list_%s' % sys][seed].values())[0])

# %%
# RSC graphs
colors = ['r--', 'm--', 'b--', 'g--', 'y--']

for seed in range(len(globals()['predictions_valid_%s' % sys])):
  fig, ax = plt.subplots()
  ranks = np.flip(np.arange(len(predictions_valid_xgb[seed])))
  for z in range(len(scoreSys)):
    globals()['line%s' % (z+1)] = plt.plot(ranks, np.sort(normalize(globals()['predictions_valid_%s' % scoreSys[z]][seed])), colors[z], label = scoreSys[z])
    plt.legend(loc = 'upper right')
    plt.title('RSC Graphs of Base Models - Seed %s' % str(seed+1))
    plt.xlabel('Rank Value')
    plt.ylabel('Normalized Score')
  plt.show()
  image_name = benchmark['name'] + '_morgan_rsc_seed_%s'% str(seed+1) + '.png'
  image_format = 'png'
  fig.savefig(image_name, format=image_format, dpi=1200)

# %%
ds_score = [[] for _ in range(5)]
for sys in scoreSys:
  for seed in range(len(ds_score)):
    loc = scoreSys.index(sys)
    scoreSys.remove(sys)
    ds = 0
    for i in range(len(scoreSys)):
      ds += np.sum(np.square(normalize(np.sort(globals()['predictions_valid_%s' % sys][seed]))-normalize(np.sort(globals()['predictions_valid_%s' % scoreSys[i]][seed]))))
    ds = ds/len(scoreSys)
    scoreSys.insert(loc, sys)
    ds_score[seed].append(ds)

# %%
ds_score
# Out:
# [[6.7742211318495045,
#   16.124832006893737,
#   9.840591044655472,
#   6.5384691987732895,
#   5.212373772591194],
#  [2.665073247884898,
#   6.420017749960043,
#   6.896982617143778,
#   5.671997590104652,
#   4.4252599841555735],
#  [4.759108062088023,
#   6.655981058157683,
#   6.245042357396448,
#   6.697313533490114,
#   3.3530413966779076],
#  [6.343084434506643,
#   14.621870502485885,
#   13.317964905197185,
#   11.09660080093754,
#   8.393136421475774],
#  [8.631201250822832,
#   6.542681678688298,
#   4.551867290327232,
#   6.557124409118316,
#   8.753541208471283]]

# %%
ds_rank = np.reciprocal(ds_score)

# %%
ds_rank
# Out:
# array([[0.14761845, 0.06201615, 0.10161991, 0.152941  , 0.19185117],
#        [0.37522421, 0.15576281, 0.14499094, 0.17630473, 0.22597542],
#        [0.21012341, 0.15024081, 0.16012702, 0.1493136 , 0.2982367 ],
#        [0.15765201, 0.0683907 , 0.07508655, 0.09011769, 0.11914497],
#        [0.11585873, 0.15284253, 0.21969006, 0.15250588, 0.11423948]])

# %%
def mean_absolute_error(y_pred, y_true):
  res = np.mean(np.abs(y_pred - y_true))
  return res

# %%
ps_score = [[] for _ in range(5)]

# %%
def spearman_corr(y_pred_rank, y_true_rank):
  n = len(y_pred_rank)
  res = 1 - 6 * np.sum((y_pred_rank - y_true_rank)**2) / (n*(n**2-1))
  return res

# %%
for sys in scoreSys:
  for seed in range(len(ps_score)):
    ps = spearman_corr(score_to_rank(globals()['predictions_valid_%s' % sys][seed]), score_to_rank(globals()['valid_y_%s'%(seed+1)]))
    ps_score[seed].append(ps)

# %%
ps_score
# Out:
# [[0.2507236010379932,
#   0.5416278528178855,
#   0.7341057289240801,
#   0.4301517067003793,
#   -0.04744993013507215],
#  [0.4655333022822543,
#   0.5380181648812297,
#   0.6803513207798257,
#   0.3892308204138665,
#   0.07967928671235613],
#  [0.43442677490185644,
#   0.5983931066604564,
#   0.6338911437886752,
#   0.3640628118969992,
#   -0.2467479539556856],
#  [0.18338711823807308,
#   0.5513673564442079,
#   0.6557405682347461,
#   0.262093286313128,
#   -0.09834320314059486],
#  [0.3951028012509149,
#   0.5208679885554595,
#   0.5352651540355313,
#   0.5048240069199548,
#   -0.15793632310865657]]

# %%
def powerset(s):
    x = len(s)
    ls = []
    for i in range(1 << x):
        ls.append([s[j] for j in range(x) if (i & (1 << j))])
    return ls[1:]

models = powerset(scoreSys)

def myFunc(e):
  return len(e)

models.sort(key=myFunc)

models_list = []
for i in range(len(models)):
  if len(models[i]) == 1:
    models_list.append(models[i][0])
  elif len(models[i]) == 2:
    models_list.append(models[i][0]+'&'+models[i][1])
  elif len(models[i]) == 3:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2])
  elif len(models[i]) == 4:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3])
  elif len(models[i]) == 5:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3]+'&'+models[i][4])

# %% [markdown]
# # Perform average score combinations

# %%
avg_score_combine_seed1 = pd.DataFrame({'xgb':predictions_test_xgb[0], 'rf':predictions_test_rf[0], 'svm':predictions_test_svm[0], 'adb':predictions_test_adb[0], 'cnn':predictions_test_cnn[0]})
avg_score_combine_seed2 = pd.DataFrame({'xgb':predictions_test_xgb[1], 'rf':predictions_test_rf[1], 'svm':predictions_test_svm[1], 'adb':predictions_test_adb[1], 'cnn':predictions_test_cnn[1]})
avg_score_combine_seed3 = pd.DataFrame({'xgb':predictions_test_xgb[2], 'rf':predictions_test_rf[2], 'svm':predictions_test_svm[2], 'adb':predictions_test_adb[2], 'cnn':predictions_test_cnn[2]})
avg_score_combine_seed4 = pd.DataFrame({'xgb':predictions_test_xgb[3], 'rf':predictions_test_rf[3], 'svm':predictions_test_svm[3], 'adb':predictions_test_adb[3], 'cnn':predictions_test_cnn[3]})
avg_score_combine_seed5 = pd.DataFrame({'xgb':predictions_test_xgb[4], 'rf':predictions_test_rf[4], 'svm':predictions_test_svm[4], 'adb':predictions_test_adb[4], 'cnn':predictions_test_cnn[4]})

# %%
def avg_score_combine(models_list, single_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]+single_score[j.split('&')[4]]) / 5

# %%
avg_score_combine(models_list, avg_score_combine_seed1)
avg_score_combine(models_list, avg_score_combine_seed2)
avg_score_combine(models_list, avg_score_combine_seed3)
avg_score_combine(models_list, avg_score_combine_seed4)
avg_score_combine(models_list, avg_score_combine_seed5)

# %% [markdown]
# # Perform average rank combinations

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
avg_rank_combine_seed1 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[0]), 'rf':score_to_rank(predictions_test_rf[0]), 'svm':score_to_rank(predictions_test_svm[0]), 'adb':score_to_rank(predictions_test_adb[0]), 'cnn':score_to_rank(predictions_test_cnn[0])})
avg_rank_combine_seed2 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[1]), 'rf':score_to_rank(predictions_test_rf[1]), 'svm':score_to_rank(predictions_test_svm[1]), 'adb':score_to_rank(predictions_test_adb[1]), 'cnn':score_to_rank(predictions_test_cnn[1])})
avg_rank_combine_seed3 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[2]), 'rf':score_to_rank(predictions_test_rf[2]), 'svm':score_to_rank(predictions_test_svm[2]), 'adb':score_to_rank(predictions_test_adb[2]), 'cnn':score_to_rank(predictions_test_cnn[2])})
avg_rank_combine_seed4 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[3]), 'rf':score_to_rank(predictions_test_rf[3]), 'svm':score_to_rank(predictions_test_svm[3]), 'adb':score_to_rank(predictions_test_adb[3]), 'cnn':score_to_rank(predictions_test_cnn[3])})
avg_rank_combine_seed5 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[4]), 'rf':score_to_rank(predictions_test_rf[4]), 'svm':score_to_rank(predictions_test_svm[4]), 'adb':score_to_rank(predictions_test_adb[4]), 'cnn':score_to_rank(predictions_test_cnn[4])})

# %%
def avg_rank_combine(models_list, single_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]+single_rank[j.split('&')[4]]) / 5

# %%
avg_rank_combine(models_list, avg_rank_combine_seed1)
avg_rank_combine(models_list, avg_rank_combine_seed2)
avg_rank_combine(models_list, avg_rank_combine_seed3)
avg_rank_combine(models_list, avg_rank_combine_seed4)
avg_rank_combine(models_list, avg_rank_combine_seed5)

# %% [markdown]
# # Perform weighted score combination by diversity strength

# %%
ds_score_combine_seed1 = pd.DataFrame()
ds_score_combine_seed2 = pd.DataFrame()
ds_score_combine_seed3 = pd.DataFrame()
ds_score_combine_seed4 = pd.DataFrame()
ds_score_combine_seed5 = pd.DataFrame()

# %%
def ds_score_combine(models_list, single_score, ds_score_combine, ds_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])]+single_score[j.split('&')[4]]*ds_score[scoreSys.index(j.split('&')[4])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])] + ds_score[scoreSys.index(j.split('&')[4])])

# %%
ds_score_combine(models_list, avg_score_combine_seed1, ds_score_combine_seed1, ds_score[0])
ds_score_combine(models_list, avg_score_combine_seed2, ds_score_combine_seed2, ds_score[1])
ds_score_combine(models_list, avg_score_combine_seed3, ds_score_combine_seed3, ds_score[2])
ds_score_combine(models_list, avg_score_combine_seed4, ds_score_combine_seed4, ds_score[3])
ds_score_combine(models_list, avg_score_combine_seed5, ds_score_combine_seed5, ds_score[4])

# %% [markdown]
# # Perform weighted rank combination by diversity strength

# %%
ds_rank_combine_seed1 = pd.DataFrame()
ds_rank_combine_seed2 = pd.DataFrame()
ds_rank_combine_seed3 = pd.DataFrame()
ds_rank_combine_seed4 = pd.DataFrame()
ds_rank_combine_seed5 = pd.DataFrame()

# %%
def ds_rank_combine(models_list, single_rank, ds_rank_combine, ds_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])]+single_rank[j.split('&')[4]]*ds_rank[scoreSys.index(j.split('&')[4])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])] + ds_rank[scoreSys.index(j.split('&')[4])])

# %%
ds_rank_combine(models_list, avg_rank_combine_seed1, ds_rank_combine_seed1, ds_rank[0])
ds_rank_combine(models_list, avg_rank_combine_seed2, ds_rank_combine_seed2, ds_rank[1])
ds_rank_combine(models_list, avg_rank_combine_seed3, ds_rank_combine_seed3, ds_rank[2])
ds_rank_combine(models_list, avg_rank_combine_seed4, ds_rank_combine_seed4, ds_rank[3])
ds_rank_combine(models_list, avg_rank_combine_seed5, ds_rank_combine_seed5, ds_rank[4])

# %% [markdown]
# # Perform weighted score combination by performance strength (Spearman)

# %%
ps_score_combine_seed1 = pd.DataFrame()
ps_score_combine_seed2 = pd.DataFrame()
ps_score_combine_seed3 = pd.DataFrame()
ps_score_combine_seed4 = pd.DataFrame()
ps_score_combine_seed5 = pd.DataFrame()

# %%
def ps_score_combine(models_list, single_score, ps_score_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])])+single_score[j.split('&')[4]]*(ps_score[scoreSys.index(j.split('&')[4])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])] + ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_score_combine(models_list, avg_score_combine_seed1, ps_score_combine_seed1, ps_score[0])
ps_score_combine(models_list, avg_score_combine_seed2, ps_score_combine_seed2, ps_score[1])
ps_score_combine(models_list, avg_score_combine_seed3, ps_score_combine_seed3, ps_score[2])
ps_score_combine(models_list, avg_score_combine_seed4, ps_score_combine_seed4, ps_score[3])
ps_score_combine(models_list, avg_score_combine_seed5, ps_score_combine_seed5, ps_score[4])

# %% [markdown]
# # Perform weighted rank combination by performance strength

# %%
ps_rank_combine_seed1 = pd.DataFrame()
ps_rank_combine_seed2 = pd.DataFrame()
ps_rank_combine_seed3 = pd.DataFrame()
ps_rank_combine_seed4 = pd.DataFrame()
ps_rank_combine_seed5 = pd.DataFrame()

# %%
def ps_rank_combine(models_list, single_rank, ps_rank_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + 1 / ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])])+single_rank[j.split('&')[4]]*(1 / ps_score[scoreSys.index(j.split('&')[4])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + 1 / ps_score[scoreSys.index(j.split('&')[3])] + 1 / ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_rank_combine(models_list, avg_rank_combine_seed1, ps_rank_combine_seed1, ps_score[0])
ps_rank_combine(models_list, avg_rank_combine_seed2, ps_rank_combine_seed2, ps_score[1])
ps_rank_combine(models_list, avg_rank_combine_seed3, ps_rank_combine_seed3, ps_score[2])
ps_rank_combine(models_list, avg_rank_combine_seed4, ps_rank_combine_seed4, ps_score[3])
ps_rank_combine(models_list, avg_rank_combine_seed5, ps_rank_combine_seed5, ps_score[4])

# %%
avg_rank_combine_seed1.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed2.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed3.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed4.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed5.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)

# %% [markdown]
# # Calculate Spearman's rank correlation

# %%
y_test_rank = score_to_rank(y_test)

# %%
def get_spearman_corr(y_pred_rank, y_true_rank):
  n = len(y_pred_rank)
  res = 1 - 6 * np.sum((y_pred_rank - y_true_rank)**2) / (n*(n**2-1))
  return res

# %%
rank_combine_list = np.hstack((np.array(avg_rank_combine_seed1.columns), np.array(ds_rank_combine_seed1.columns), np.array(ps_rank_combine_seed1.columns)))
spearman_corr = pd.DataFrame(index = rank_combine_list)
for i in range(1, 6):
  sc_avg, sc_ds, sc_ps = [], [], []
  for col in globals()['avg_rank_combine_seed%s' %i].columns:
    sc = get_spearman_corr(np.array(globals()['avg_rank_combine_seed%s' %i][col]), y_test_rank)
    sc_avg.append(sc)
  for col in globals()['ds_rank_combine_seed%s' %i].columns:
    sc = get_spearman_corr(np.array(globals()['ds_rank_combine_seed%s' %i][col]), y_test_rank)
    sc_ds.append(sc)
  for col in globals()['ps_rank_combine_seed%s' %i].columns:
    sc = get_spearman_corr(np.array(globals()['ps_rank_combine_seed%s' %i][col]), y_test_rank)
    sc_ps.append(sc)
  spearman_corr['seed'+str(i)] = np.hstack((sc_avg, sc_ds, sc_ps))

# %%
pd.set_option("display.max_rows", None)

# %%
spearman_corr['avg_spearman'] = spearman_corr.mean(axis=1)

# %%
spearman_corr.sort_values(by='avg_spearman', ascending=False)
# Out:
#                             seed1     seed2        seed3       seed4  \
# rf&svm_ds_r              0.648590  0.641873     0.628201    0.630439
# rf&svm_r                 0.641003  0.643071     0.627408    0.629301
# rf&svm_ps_r              0.631622  0.638543     0.626566    0.626313
# rf&svm&adb_r             0.636189  0.648205     0.613533    0.616949
# rf&svm&adb&cnn_r         0.625193  0.642724     0.616185    0.596744
# rf&svm&adb_ds_r          0.599266  0.642485     0.615701    0.607034
# xgb&rf&svm&adb_r         0.622185  0.632614     0.607589    0.613692
# xgb&rf&svm_r             0.617793  0.626186     0.615774    0.614428
# xgb&rf&svm&adb&cnn_r     0.618066  0.631021     0.612236    0.599618
# rf&svm&adb_ps_r          0.610876  0.628973     0.580664    0.564768
# xgb&rf&svm&cnn_r         0.606535  0.610056     0.601155    0.594319
# xgb&rf&svm&adb_ds_r      0.593668  0.591586     0.601266    0.584946
# rf&svm&cnn_r             0.609906  0.610392     0.593202    0.591161
# xgb&rf&svm_ds_r          0.592385  0.570194     0.603668    0.568823
# xgb&svm&adb&cnn_r        0.597887  0.611363     0.586136    0.568724
# xgb&rf&svm&adb&cnn_ds_r  0.581672  0.595034     0.578276    0.569486
# rf&svm&adb&cnn_ds_r      0.572364  0.619564     0.564185    0.561341
# xgb&svm&adb_r            0.594076  0.611567     0.573465    0.581269
# xgb&rf&svm&adb_ps_r      0.578619  0.616312     0.582766    0.560932
# svm_r                    0.612880  0.608386     0.583838    0.580912
# svm&adb&cnn_r            0.595900  0.619271     0.579127    0.549644
# svm&adb_r                0.590721  0.624926     0.560618    0.563663
# xgb&svm_r                0.590885  0.597048     0.583819    0.575949
# xgb&rf&svm_ps_r          0.556499  0.611321     0.599863    0.532286
# svm&adb_ds_r             0.549855  0.613395     0.565979    0.550668
# xgb&svm&adb_ds_r         0.569357  0.560252     0.568286    0.552009
# xgb&rf&svm&cnn_ds_r      0.553661  0.567586     0.549806    0.552517
# xgb&svm&adb&cnn_ds_r     0.564863  0.570457     0.544690    0.541197
# xgb&rf&adb&cnn_r         0.557400  0.580372     0.560440    0.545371
# xgb&svm&cnn_r            0.581199  0.570823     0.560478    0.553315
# xgb&rf&adb_r             0.557554  0.575000     0.549691    0.564100
# rf&adb_r                 0.547986  0.578040     0.537654    0.550702
# xgb&svm&adb_ps_r         0.540869  0.586950     0.542535    0.526582
# svm&adb&cnn_ds_r         0.543608  0.583934     0.506158    0.508708
# rf&adb&cnn_r             0.541451  0.579905     0.547013    0.519536
# xgb&svm_ds_r             0.562620  0.518277     0.565779    0.516386
# rf&svm&cnn_ds_r          0.518995  0.566483     0.505809    0.535006
# xgb&rf&adb_ps_r          0.531504  0.567995     0.528494    0.524550
# xgb&rf_r                 0.526278  0.546120     0.539708    0.536304
# xgb&rf&adb_ds_r          0.520634  0.538014     0.541724    0.533713
# svm&adb_ps_r             0.535469  0.586877     0.507998    0.485724
# xgb&rf&adb&cnn_ds_r      0.519700  0.551891     0.518070    0.520028
# rf&adb_ds_r              0.468107  0.572974     0.538058    0.533947
# rf_r                     0.512202  0.546227     0.529506    0.525009
# rf&adb_ps_r              0.531905  0.563206     0.497520    0.497123
# xgb&svm_ps_r             0.499069  0.569206     0.557740    0.467344
# xgb&svm&cnn_ds_r         0.526851  0.526255     0.495194    0.511728
# svm&cnn_r                0.565210  0.538407     0.511386    0.520235
# xgb&rf&cnn_r             0.517029  0.529660     0.518966    0.511348
# xgb&rf_ps_r              0.483031  0.538703     0.522795    0.460350
# rf&adb&cnn_ds_r          0.473769  0.554370     0.468860    0.473693
# xgb&rf_ds_r              0.476556  0.490190     0.521881    0.480958
# xgb&adb&cnn_r            0.496874  0.523323     0.492846    0.471816
# xgb&adb&cnn_ds_r         0.485808  0.506780     0.448822    0.469208
# xgb&rf&cnn_ds_r          0.450226  0.504117     0.456605    0.478091
# xgb&adb_r                0.462159  0.493738     0.445819    0.475132
# xgb&adb_ps_r             0.461896  0.494624     0.441187    0.471651
# xgb&adb_ds_r             0.461408  0.470917     0.448714    0.465794
# rf&cnn_r                 0.460267  0.481179     0.448511    0.451478
# svm&cnn_ds_r             0.456918  0.461167     0.383321    0.439423
# adb&cnn_r                0.418000  0.481668     0.418147    0.371502
# adb&cnn_ds_r             0.402504  0.453084     0.319318    0.343703
# xgb&cnn_r                0.404604  0.390282     0.373201    0.371037
# xgb&cnn_ds_r             0.381855  0.420950     0.326559    0.391375
# rf&cnn_ds_r              0.295864  0.424177     0.318542    0.362757
# xgb_r                    0.347443  0.354669     0.348427    0.330445
# adb_r                    0.268059  0.395696     0.267571    0.316201
# cnn_r                    0.051686  0.002483    -0.102944   -0.022310
# svm&cnn_ps_r            -0.055927  0.153458    -1.671654   -0.328773
# rf&cnn_ps_r             -0.067596  0.165573    -1.670262   -0.352624
# xgb&cnn_ps_r            -0.253491  0.159624    -3.745238   -2.594368
# adb&cnn_ps_r            -0.119031  0.228730    -9.650410   -1.089030
# xgb&rf&svm&adb&cnn_ps_r -1.414847  0.430429    -0.513803  -12.150172
# rf&svm&cnn_ps_r         -0.206960  0.269784   -22.187408   -0.921113
# rf&svm&adb&cnn_ps_r     -0.497283  0.388184    -4.469645   -7.405884
# xgb&adb&cnn_ps_r        -0.584542  0.312374   -19.022039  -90.412801
# rf&adb&cnn_ps_r         -0.293056  0.321989  -135.171661   -2.758421
# svm&adb&cnn_ps_r        -0.270700  0.318703  -257.280801   -2.501557
# xgb&svm&cnn_ps_r        -0.449223  0.263028  -497.466626   -6.715997
# xgb&rf&cnn_ps_r         -0.485588  0.268463 -2257.353803   -7.985106
# xgb&rf&adb&cnn_ps_r     -0.959759  0.379411    -2.180462  -87.916996
# xgb&svm&adb&cnn_ps_r    -0.889734  0.378994    -2.460535 -194.688520
# xgb&rf&svm&cnn_ps_r     -0.759253  0.343852    -6.289313  -39.042147
#
#                                  seed5  avg_spearman
# rf&svm_ds_r                   0.589047      0.627630
# rf&svm_r                      0.590186      0.626194
# rf&svm_ps_r                   0.590087      0.622626
# rf&svm&adb_r                  0.593961      0.621767
# rf&svm&adb&cnn_r              0.585049      0.613179
# rf&svm&adb_ds_r               0.599080      0.612713
# xgb&rf&svm&adb_r              0.583891      0.611994
# xgb&rf&svm_r                  0.583001      0.611436
# xgb&rf&svm&adb&cnn_r          0.582415      0.608671
# rf&svm&adb_ps_r               0.592635      0.595583
# xgb&rf&svm&cnn_r              0.563565      0.595126
# xgb&rf&svm&adb_ds_r           0.594709      0.593235
# rf&svm&cnn_r                  0.547535      0.590439
# xgb&rf&svm_ds_r               0.592220      0.585458
# xgb&svm&adb&cnn_r             0.560496      0.584921
# xgb&rf&svm&adb&cnn_ds_r       0.597166      0.584327
# rf&svm&adb&cnn_ds_r           0.600647      0.583620
# xgb&svm&adb_r                 0.554791      0.583033
# xgb&rf&svm&adb_ps_r           0.576322      0.582990
# svm_r                         0.525770      0.582357
# svm&adb&cnn_r                 0.556947      0.580178
# svm&adb_r                     0.560170      0.580020
# xgb&svm_r                     0.541964      0.577933
# xgb&rf&svm_ps_r               0.572982      0.574590
# svm&adb_ds_r                  0.571503      0.570280
# xgb&svm&adb_ds_r              0.572083      0.564398
# xgb&rf&svm&cnn_ds_r           0.584523      0.561619
# xgb&svm&adb&cnn_ds_r          0.581121      0.560466
# xgb&rf&adb&cnn_r              0.545907      0.557898
# xgb&svm&cnn_r                 0.521622      0.557488
# xgb&rf&adb_r                  0.539311      0.557131
# rf&adb_r                      0.535114      0.549899
# xgb&svm&adb_ps_r              0.545245      0.548436
# svm&adb&cnn_ds_r              0.582310      0.544944
# rf&adb&cnn_r                  0.535357      0.544652
# xgb&svm_ds_r                  0.558252      0.544263
# rf&svm&cnn_ds_r               0.577530      0.540765
# xgb&rf&adb_ps_r               0.532652      0.537039
# xgb&rf_r                      0.529017      0.535485
# xgb&rf&adb_ds_r               0.543178      0.535453
# svm&adb_ps_r                  0.557604      0.534734
# xgb&rf&adb&cnn_ds_r           0.554755      0.532889
# rf&adb_ds_r                   0.535199      0.529657
# rf_r                          0.513077      0.525204
# rf&adb_ps_r                   0.533871      0.524725
# xgb&svm_ps_r                  0.527126      0.524097
# xgb&svm&cnn_ds_r              0.554420      0.522890
# svm&cnn_r                     0.462386      0.519525
# xgb&rf&cnn_r                  0.505413      0.516483
# xgb&rf_ps_r                   0.516672      0.504310
# rf&adb&cnn_ds_r               0.549039      0.503946
# xgb&rf_ds_r                   0.537870      0.501491
# xgb&adb&cnn_r                 0.495998      0.496171
# xgb&adb&cnn_ds_r              0.503603      0.482844
# xgb&rf&cnn_ds_r               0.520224      0.481853
# xgb&adb_r                     0.456637      0.466697
# xgb&adb_ps_r                  0.455260      0.464924
# xgb&adb_ds_r                  0.454701      0.460307
# rf&cnn_r                      0.435690      0.455425
# svm&cnn_ds_r                  0.526978      0.453561
# adb&cnn_r                     0.447961      0.427456
# adb&cnn_ds_r                  0.468890      0.397500
# xgb&cnn_r                     0.387043      0.385233
# xgb&cnn_ds_r                  0.388343      0.381816
# rf&cnn_ds_r                   0.469868      0.374242
# xgb_r                         0.358816      0.347960
# adb_r                         0.357381      0.320981
# cnn_r                        -0.013610     -0.016939
# svm&cnn_ps_r                 -0.729360     -0.526451
# rf&cnn_ps_r                  -0.707356     -0.526453
# xgb&cnn_ps_r                 -1.213214     -1.529337
# adb&cnn_ps_r                 -0.914219     -2.308792
# xgb&rf&svm&adb&cnn_ps_r      -7.541198     -4.237918
# rf&svm&cnn_ps_r              -3.556802     -5.320500
# rf&svm&adb&cnn_ps_r         -94.496443    -21.296214
# xgb&adb&cnn_ps_r             -8.671867    -23.675775
# rf&adb&cnn_ps_r              -4.348726    -28.449975
# svm&adb&cnn_ps_r             -4.261943    -52.799260
# xgb&svm&cnn_ps_r             -6.812976   -102.236359
# xgb&rf&cnn_ps_r              -6.982946   -454.507796
# xgb&rf&adb&cnn_ps_r       -3101.411234   -638.417808
# xgb&svm&adb&cnn_ps_r     -13470.617923  -2733.655544
# xgb&rf&svm&cnn_ps_r     -176331.464462 -35275.442265
