# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm #progress bar
import rdkit
from rdkit import Chem #Chemistry
from rdkit.Chem import rdMolDescriptors #molecular descriptors
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
rdkit.__version__
# Out:
# '2023.03.2'

# %%
import xgboost
import sklearn
import tensorflow as tf
from xgboost import XGBClassifier
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from sklearn.model_selection import train_test_split #ML training
from sklearn.model_selection import RandomizedSearchCV
#from yellowbrick.regressor import prediction_error, ResidualsPlot
from tdc.single_pred import ADME
from tdc.benchmark_group import admet_group
from tdc import BenchmarkGroup
import warnings
warnings.filterwarnings("ignore")

# %%
def pred_prob_to_score(pred_prob):
    res = []
    for i in range(len(pred_prob)):
        res.append(pred_prob[i][1])
    res = np.array(res)
    return res

# %%
group = admet_group(path = 'data/')

pred_valid_list_xgb = []
pred_valid_list_rf = []
pred_valid_list_svm = []
pred_valid_list_adb = []
pred_valid_list_cnn = []
        
pred_test_list_xgb = []
pred_test_list_rf = []
pred_test_list_svm = []
pred_test_list_adb = []
pred_test_list_cnn = []

best_params_list_xgb = []
best_params_list_svm = []

for seed in [1, 2, 3, 4, 5]:
    pred_valid_xgb = {}
    pred_valid_rf = {}
    pred_valid_svm = {}
    pred_valid_adb = {}
    pred_valid_cnn = {}

    pred_test_xgb = {}
    pred_test_rf = {}
    pred_test_svm = {}
    pred_test_adb = {}
    pred_test_cnn = {}

    benchmark = group.get('HIA_Hou')
    name = benchmark['name']
    train_val, test = benchmark['train_val'], benchmark['test']
    train, valid = group.get_train_valid_split(benchmark = name, split_type = 'default', seed = seed)

    PandasTools.AddMoleculeColumnToFrame(train, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in train['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = train['Y']
    train = pd.DataFrame(ecfp6_bits, index = train.Drug, columns=ecfp6_name).reset_index(drop = False)
    train['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(valid, smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in valid['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = valid['Y']
    valid = pd.DataFrame(ecfp6_bits, index = valid.Drug, columns=ecfp6_name).reset_index(drop = False)
    valid['Y'] = Y

    PandasTools.AddMoleculeColumnToFrame(benchmark['test'], smilesCol='Drug')
    radius=2
    nBits=1024
    ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,radius=radius, nBits=nBits) for x in benchmark['test']['ROMol']]
    ecfp6_name = [f'Bit_{i}' for i in range(nBits)]
    ecfp6_bits = [list(l) for l in ECFP6]
    Y = benchmark['test']['Y']
    benchmark['test'] = pd.DataFrame(ecfp6_bits, index = benchmark['test'].Drug, columns=ecfp6_name).reset_index(drop = False)
    benchmark['test']['Y'] = Y

    train_X = train.drop(columns = ["Drug","Y"])
    train_y = train.Y
    valid_X = valid.drop(columns = ["Drug","Y"])
    globals()['valid_y_%s'%seed] = valid.Y
    test_X = benchmark['test'].drop(columns = ["Drug","Y"])
    test_y = benchmark['test'].Y


    #XGBoost + Morgan
    xgb_parameters = {'objective':['binary:logistic'],
    'booster':['gbtree','gblinear'],
    'learning_rate': [0.1],
    'max_depth': [7,10,15,20],
    'min_child_weight': [10,15,20,25],
    'colsample_bytree': [0.8, 0.9, 1],
    'n_estimators': [300,400,500,600],
    "reg_alpha"   : [0.5,0.2,1],
    "reg_lambda"  : [2,3,5],
    "gamma"       : [1,2,3]}

    xgb_model = XGBClassifier()
    grid_obj_xgb = RandomizedSearchCV(xgb_model, xgb_parameters, cv=5, n_iter=15, scoring = 'roc_auc', verbose=5, n_jobs=1)
    grid_obj_xgb.fit(train_X, train_y, verbose = 1)
    y_pred_valid_xgb = grid_obj_xgb.predict_proba(valid_X)
    y_pred_test_xgb = grid_obj_xgb.predict_proba(test_X)
    pred_valid_xgb[name] = pred_prob_to_score(y_pred_valid_xgb)
    pred_valid_list_xgb.append(pred_valid_xgb)
    pred_test_xgb[name] = pred_prob_to_score(y_pred_test_xgb)
    pred_test_list_xgb.append(pred_test_xgb)
    bp_xgb = grid_obj_xgb.best_params_
    best_params_list_xgb.append(bp_xgb)

    #Random Forest + Morgan
    rf_model = RandomForestClassifier()
    rf_model.fit(train_X, train_y)
    y_pred_valid_rf = rf_model.predict_proba(valid_X)
    y_pred_test_rf = rf_model.predict_proba(test_X)
    pred_valid_rf[name] = pred_prob_to_score(y_pred_valid_rf)
    pred_valid_list_rf.append(pred_valid_rf)
    pred_test_rf[name] = pred_prob_to_score(y_pred_test_rf)
    pred_test_list_rf.append(pred_test_rf)

    #SVM + Morgan
    svm_parameters = {
        'C': [0.1, 1, 10, 100, 1000],
        'gamma': [0.0001, 0.001, 0.01, 0.1, 1]
    }
    svm_model = SVC(kernel="rbf", probability=True)
    grid_obj_svm = RandomizedSearchCV(svm_model, svm_parameters, cv=5, n_iter=15, verbose=5, n_jobs=1)
    grid_obj_svm.fit(train_X, train_y)
    y_pred_valid_svm = grid_obj_svm.predict_proba(valid_X)
    y_pred_test_svm = grid_obj_svm.predict_proba(test_X)
    pred_valid_svm[name] = pred_prob_to_score(y_pred_valid_svm)
    pred_valid_list_svm.append(pred_valid_svm)
    pred_test_svm[name] = pred_prob_to_score(y_pred_test_svm)
    pred_test_list_svm.append(pred_test_svm)
    bp_svm = grid_obj_svm.best_params_
    best_params_list_svm.append(bp_svm)

    # AdaBoost + Morgan
    DTC = DecisionTreeClassifier(max_depth=4)
    adb_model = AdaBoostClassifier(n_estimators=300, base_estimator=DTC, learning_rate=1)
    adb_model.fit(train_X, train_y)
    y_pred_valid_adb = adb_model.predict_proba(valid_X)
    y_pred_test_adb = adb_model.predict_proba(test_X)
    pred_valid_adb[name] = pred_prob_to_score(y_pred_valid_adb)
    pred_valid_list_adb.append(pred_valid_adb)
    pred_test_adb[name] = pred_prob_to_score(y_pred_test_adb)
    pred_test_list_adb.append(pred_test_adb)

    #CNN + Morgan
    train_X_cnn = train_X.to_numpy()
    valid_X_cnn = valid_X.to_numpy()
    test_X_cnn = test_X.to_numpy()
    train_X_cnn = train_X_cnn.reshape(train_X_cnn.shape[0], train_X_cnn.shape[1], 1)
    valid_X_cnn = valid_X_cnn.reshape(valid_X_cnn.shape[0], valid_X_cnn.shape[1], 1)
    test_X_cnn = test_X_cnn.reshape(test_X_cnn.shape[0], test_X_cnn.shape[1], 1)
    train_X = train_X.astype('float32')
    valid_X = valid_X.astype('float32')
    test_X = test_X.astype('float32')
    cnn_model = Sequential()
    cnn_model.add(Conv1D(32, 2, padding="valid", activation="relu", input_shape=(1024,1)))
    cnn_model.add(Flatten())
    cnn_model.add(Dense(64, activation="relu"))
    cnn_model.add(Dense(1,activation='sigmoid'))
    cnn_model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer="adam", metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.FalseNegatives()])
    cnn_model.fit(train_X_cnn, train_y, batch_size=12, epochs=10, verbose=0)
    y_pred_valid_cnn = cnn_model.predict(valid_X_cnn)
    y_pred_test_cnn = cnn_model.predict(test_X_cnn)
    y_pred_valid_cnn_copy = []
    for i in range(len(y_pred_valid_cnn)):
        y_pred_valid_cnn_copy.append(y_pred_valid_cnn[i][0])
    y_pred_test_cnn_copy = []
    for i in range(len(y_pred_test_cnn)):
        y_pred_test_cnn_copy.append(y_pred_test_cnn[i][0])
    pred_valid_cnn[name] = np.array(y_pred_valid_cnn_copy)
    pred_valid_list_cnn.append(pred_valid_cnn)
    pred_test_cnn[name] = np.array(y_pred_test_cnn_copy)
    pred_test_list_cnn.append(pred_test_cnn)

xgb_perform = group.evaluate_many(pred_test_list_xgb)
rf_perform = group.evaluate_many(pred_test_list_rf)
svm_perform = group.evaluate_many(pred_test_list_svm)
adb_perform = group.evaluate_many(pred_test_list_adb)
cnn_perform = group.evaluate_many(pred_test_list_cnn)
# Out:
# Found local copy...
# generating training, validation splits...
# 100%|██████████| 461/461 [00:00<00:00, 2269.26it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.742 total time=  17.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.716 total time=  20.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.447 total time=  19.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.262 total time=  16.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.607 total time=  32.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  24.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  30.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.444 total time=  28.3s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.178 total time=  29.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  27.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.639 total time=  14.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  14.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.399 total time=  15.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.326 total time=  14.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.631 total time=  15.2s
# [04:22:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  22.8s
# [04:22:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  23.4s
# [04:22:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  22.9s
# [04:23:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  23.5s
# [04:23:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  23.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  22.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  22.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.444 total time=  22.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.178 total time=  21.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  22.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.720 total time=  47.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.692 total time= 1.0min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.469 total time=  46.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.267 total time=  45.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.576 total time=  45.8s
# [04:30:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.500 total time=  18.9s
# [04:30:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.500 total time=  17.6s
# [04:30:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.500 total time=  17.4s
# [04:31:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.500 total time=  17.2s
# [04:31:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.500 total time=  17.1s
# [04:31:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  12.8s
# [04:31:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  13.0s
# [04:32:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  13.1s
# [04:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  13.1s
# [04:32:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  13.3s
# [04:32:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  17.0s
# [04:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  16.8s
# [04:33:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  16.5s
# [04:33:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  16.3s
# [04:33:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  15.3s
# [04:34:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  18.7s
# [04:34:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  19.8s
# [04:34:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  20.3s
# [04:35:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  19.6s
# [04:35:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  20.8s
# [04:35:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  24.4s
# [04:36:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  24.8s
# [04:36:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  24.7s
# [04:36:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  23.8s
# [04:37:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  22.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  28.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  29.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.399 total time=  29.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.239 total time=  29.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.574 total time=  28.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.840 total time=  46.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.615 total time=  46.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.542 total time=  51.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.233 total time=  51.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.594 total time=  53.3s
# [04:44:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.5s
# [04:44:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  24.5s
# [04:45:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.2s
# [04:45:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.0s
# [04:45:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  21.3s
# [04:46:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  22.1s
# [04:46:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  22.1s
# [04:46:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  22.2s
# [04:47:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  22.5s
# [04:47:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  22.6s
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ....................C=100, gamma=1;, score=0.889 total time=   0.2s
# [CV 2/5] END ....................C=100, gamma=1;, score=0.889 total time=   0.2s
# [CV 3/5] END ....................C=100, gamma=1;, score=0.889 total time=   0.2s
# [CV 4/5] END ....................C=100, gamma=1;, score=0.887 total time=   0.2s
# [CV 5/5] END ....................C=100, gamma=1;, score=0.900 total time=   0.2s
# [CV 1/5] END ..............C=1000, gamma=0.0001;, score=0.926 total time=   0.1s
# [CV 2/5] END ..............C=1000, gamma=0.0001;, score=0.914 total time=   0.1s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.926 total time=   0.1s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.863 total time=   0.1s
# [CV 5/5] END ..............C=1000, gamma=0.0001;, score=0.925 total time=   0.1s
# [CV 1/5] END .................C=100, gamma=0.01;, score=0.938 total time=   0.1s
# [CV 2/5] END .................C=100, gamma=0.01;, score=0.901 total time=   0.1s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.914 total time=   0.1s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.875 total time=   0.1s
# [CV 5/5] END .................C=100, gamma=0.01;, score=0.925 total time=   0.1s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.900 total time=   0.2s
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.889 total time=   0.2s
# [CV 2/5] END ...................C=1000, gamma=1;, score=0.889 total time=   0.2s
# [CV 3/5] END ...................C=1000, gamma=1;, score=0.889 total time=   0.2s
# [CV 4/5] END ...................C=1000, gamma=1;, score=0.887 total time=   0.2s
# [CV 5/5] END ...................C=1000, gamma=1;, score=0.900 total time=   0.2s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.887 total time=   0.1s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.900 total time=   0.1s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.914 total time=   0.1s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.914 total time=   0.1s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.901 total time=   0.1s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.887 total time=   0.1s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.912 total time=   0.1s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.900 total time=   0.2s
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.889 total time=   0.2s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.889 total time=   0.2s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.889 total time=   0.2s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.887 total time=   0.2s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.900 total time=   0.2s
# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.900 total time=   0.2s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.889 total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.887 total time=   0.1s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.900 total time=   0.1s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.889 total time=   0.2s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.900 total time=   0.2s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.926 total time=   0.1s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.926 total time=   0.1s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.926 total time=   0.1s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.875 total time=   0.1s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.925 total time=   0.1s
# [CV 1/5] END ...............C=100, gamma=0.0001;, score=0.914 total time=   0.1s
# [CV 2/5] END ...............C=100, gamma=0.0001;, score=0.914 total time=   0.1s
# [CV 3/5] END ...............C=100, gamma=0.0001;, score=0.901 total time=   0.1s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 5/5] END ...............C=100, gamma=0.0001;, score=0.912 total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.889 total time=   0.1s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.889 total time=   0.1s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.889 total time=   0.1s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.887 total time=   0.1s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.900 total time=   0.1s
# 2/2 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# generating training, validation splits...
# 100%|██████████| 461/461 [00:00<00:00, 2233.95it/s]
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.505 total time=  35.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.660 total time=  34.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.413 total time=  34.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.434 total time=  34.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  34.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.505 total time=  34.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.660 total time=  34.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.400 total time=  34.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.419 total time=  33.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  33.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.411 total time=  22.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.484 total time=  23.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  22.6s
# [04:57:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  23.0s
# [04:57:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  23.3s
# [04:57:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  24.0s
# [04:58:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  23.6s
# [04:58:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  24.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.579 total time=  57.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.799 total time=  55.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.512 total time=  57.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.490 total time=  52.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=600, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.840 total time=  54.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.551 total time=  37.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.713 total time=  34.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.509 total time=  35.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.454 total time=  33.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.786 total time=  37.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.505 total time=  29.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.660 total time=  29.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.420 total time=  30.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.430 total time=  30.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.500 total time=  29.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.507 total time=  30.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  28.3s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.411 total time=  28.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.484 total time=  28.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.500 total time=  28.3s
# [05:11:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  14.0s
# [05:11:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  14.1s
# [05:12:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  14.0s
# [05:12:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  13.9s
# [05:12:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=300, objective=binary:logistic, reg_alpha=0.2, reg_lambda=5;, score=0.500 total time=  14.3s
# [05:12:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  23.4s
# [05:13:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  22.3s
# [05:13:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  21.3s
# [05:13:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  21.1s
# [05:14:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.500 total time=  21.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.505 total time=  22.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  23.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.400 total time=  25.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.484 total time=  26.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.2, reg_lambda=3;, score=0.500 total time=  27.3s
# ...
# [07:00:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  18.5s
# [07:01:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=15, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=2;, score=0.500 total time=  18.7s
# [07:01:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  18.5s
# [07:01:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  19.2s
# [07:02:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  19.0s
# [07:02:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  19.9s
# [07:02:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } are not used.
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=5;, score=0.500 total time=  19.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.620 total time=  24.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.733 total time=  22.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.668 total time=  22.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.556 total time=  25.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=25, n_estimators=400, objective=binary:logistic, reg_alpha=1, reg_lambda=2;, score=0.663 total time=  25.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.629 total time=  30.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.852 total time=  30.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.701 total time=  29.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.671 total time=  30.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=0.2, reg_lambda=2;, score=0.752 total time=  29.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.594 total time=  39.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  38.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.500 total time=  39.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.556 total time=  40.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.648 total time=  34.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.616 total time=  28.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.831 total time=  31.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.685 total time=  30.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.598 total time=  30.3s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=3;, score=0.737 total time=  28.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.626 total time=  24.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.844 total time=  24.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.673 total time=  24.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.663 total time=  23.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=20, n_estimators=400, objective=binary:logistic, reg_alpha=0.5, reg_lambda=3;, score=0.717 total time=  24.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.610 total time=  30.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.793 total time=  30.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.699 total time=  30.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.598 total time=  30.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=500, objective=binary:logistic, reg_alpha=1, reg_lambda=5;, score=0.710 total time=  29.0s
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ...............C=1000, gamma=0.001;, score=0.938 total time=   0.1s
# [CV 2/5] END ...............C=1000, gamma=0.001;, score=0.900 total time=   0.1s
# [CV 3/5] END ...............C=1000, gamma=0.001;, score=0.937 total time=   0.1s
# [CV 4/5] END ...............C=1000, gamma=0.001;, score=0.937 total time=   0.1s
# [CV 5/5] END ...............C=1000, gamma=0.001;, score=0.975 total time=   0.1s
# [CV 1/5] END ..............C=1000, gamma=0.0001;, score=0.938 total time=   0.1s
# [CV 2/5] END ..............C=1000, gamma=0.0001;, score=0.900 total time=   0.1s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.924 total time=   0.1s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.924 total time=   0.1s
# [CV 5/5] END ..............C=1000, gamma=0.0001;, score=0.975 total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.887 total time=   0.1s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.887 total time=   0.1s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.899 total time=   0.1s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.886 total time=   0.1s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.886 total time=   0.1s
# [CV 1/5] END ................C=1000, gamma=0.01;, score=0.925 total time=   0.1s
# [CV 2/5] END ................C=1000, gamma=0.01;, score=0.912 total time=   0.2s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.937 total time=   0.2s
# [CV 4/5] END ................C=1000, gamma=0.01;, score=0.937 total time=   0.2s
# [CV 5/5] END ................C=1000, gamma=0.01;, score=0.975 total time=   0.1s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.887 total time=   0.1s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.887 total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.899 total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.886 total time=   0.1s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.899 total time=   0.1s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.899 total time=   0.2s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.887 total time=   0.2s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.887 total time=   0.2s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.899 total time=   0.2s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.886 total time=   0.2s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.886 total time=   0.2s
# [CV 1/5] END ...............C=0.1, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 2/5] END ...............C=0.1, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 3/5] END ...............C=0.1, gamma=0.0001;, score=0.899 total time=   0.1s
# [CV 4/5] END ...............C=0.1, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 5/5] END ...............C=0.1, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.899 total time=   0.1s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.899 total time=   0.2s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.887 total time=   0.2s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.899 total time=   0.2s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.886 total time=   0.2s
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.887 total time=   0.2s
# [CV 2/5] END ...................C=1000, gamma=1;, score=0.887 total time=   0.2s
# [CV 3/5] END ...................C=1000, gamma=1;, score=0.899 total time=   0.2s
# [CV 4/5] END ...................C=1000, gamma=1;, score=0.886 total time=   0.2s
# [CV 5/5] END ...................C=1000, gamma=1;, score=0.886 total time=   0.2s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.887 total time=   0.1s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.899 total time=   0.1s
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.886 total time=   0.1s
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.887 total time=   0.2s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.887 total time=   0.2s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.899 total time=   0.2s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.886 total time=   0.2s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.886 total time=   0.2s
# [CV 1/5] END ...............C=100, gamma=0.0001;, score=0.912 total time=   0.1s
# [CV 2/5] END ...............C=100, gamma=0.0001;, score=0.900 total time=   0.1s
# [CV 3/5] END ...............C=100, gamma=0.0001;, score=0.899 total time=   0.1s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.899 total time=   0.1s
# [CV 5/5] END ...............C=100, gamma=0.0001;, score=0.911 total time=   0.1s
# 2/2 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
print("xgb_perform:", xgb_perform, "\n rf_perform:", rf_perform, "\n svm_perform:", svm_perform, "\n adb_perform:", adb_perform, "\n cnn_perform:", cnn_perform)
# Out:
# xgb_perform: {'hia_hou': [0.807, 0.022]}
#  rf_perform: {'hia_hou': [0.919, 0.016]}
#  svm_perform: {'hia_hou': [0.932, 0.009]}
#  adb_perform: {'hia_hou': [0.95, 0.017]}
#  cnn_perform: {'hia_hou': [0.873, 0.016]}

# %%
y_test = benchmark['test'].Y
y_test = np.array(y_test)

# %%
def rank_object(array): # convert scores into ranks
    arg_a = np.argsort(array)
    b = np.flip(np.arange(len(arg_a)))
    a = np.zeros_like(arg_a)
    for i in range(len(arg_a)):
        a[arg_a[i]] = b[i]
    return a

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
def normalize(array): # define function for normalization of scores
    maximum = np.max(array)
    minimum = np.min(array)
    norm_list = []
    for i in range(len(array)):
        norm_list.append((array[i]-minimum)/(maximum-minimum))
    return np.array(norm_list)

# %%
predictions_valid_xgb = []
predictions_valid_rf = []
predictions_valid_svm = []
predictions_valid_adb = []
predictions_valid_cnn = []

predictions_test_xgb = []
predictions_test_rf = []
predictions_test_svm = []
predictions_test_adb = []
predictions_test_cnn = []

scoreSys = ['xgb', 'rf', 'svm', 'adb', 'cnn']

for sys in scoreSys:
  for seed in range(len(globals()['pred_valid_list_%s' % sys])):
    globals()['predictions_valid_%s' % sys].append(list(globals()['pred_valid_list_%s' % sys][seed].values())[0])

for sys in scoreSys:
  for seed in range(len(globals()['pred_test_list_%s' % sys])):
    globals()['predictions_test_%s' % sys].append(list(globals()['pred_test_list_%s' % sys][seed].values())[0])

# %%
# RSC graphs
colors = ['r--', 'm--', 'b--', 'g--', 'y--']

for seed in range(len(globals()['predictions_valid_%s' % sys])):
  ranks = np.flip(np.arange(len(predictions_valid_xgb[seed])))
  fig, ax = plt.subplots()
  for z in range(len(scoreSys)):
    globals()['line%s' % (z+1)] = plt.plot(ranks, np.sort(normalize(globals()['predictions_valid_%s' % scoreSys[z]][seed])), colors[z], label = scoreSys[z])
    plt.legend(loc = 'upper right', bbox_to_anchor=(1.2, 1))
    plt.title('RSC Graphs of Base Models - Seed %s' % str(seed+1))
    plt.xlabel('Rank Value')
    plt.ylabel('Normalized Score')
  plt.show()
  image_name = benchmark['name'] + '_morgan_rsc_seed_%s'% str(seed+1) + '.png'
  image_format = 'png'
  fig.savefig(image_name, format=image_format, dpi=1200, bbox_inches='tight')

# %%
ds_score = [[] for _ in range(5)]
for sys in scoreSys:
  for seed in range(len(ds_score)):
    loc = scoreSys.index(sys)
    scoreSys.remove(sys)
    ds = 0
    for i in range(len(scoreSys)):
      ds += np.sum(np.square(normalize(np.sort(globals()['predictions_valid_%s' % sys][seed]))-normalize(np.sort(globals()['predictions_valid_%s' % scoreSys[i]][seed]))))
    ds = ds/len(scoreSys)
    scoreSys.insert(loc, sys)
    ds_score[seed].append(ds)

# %%
ds_score
# Out:
# [[1.2364888524462696,
#   2.472103412821555,
#   0.9347624251977574,
#   1.6570512296514315,
#   1.5358930476812749],
#  [2.5033838389367933,
#   1.9482083522992812,
#   1.2950417237749612,
#   2.3569141269591087,
#   2.3235979196413177],
#  [4.416225655084977,
#   2.183852340833128,
#   2.9231632005595873,
#   3.7215400880220493,
#   4.57282905061682],
#  [4.692472050029721,
#   2.037084301800242,
#   1.5664438141208463,
#   2.686263598302922,
#   2.580079025989644],
#  [5.515986093067729,
#   2.192064046411862,
#   1.7335466230420022,
#   3.5102883878186644,
#   3.516356185772017]]

# %%
ds_rank = np.reciprocal(ds_score)

# %%
ds_rank
# Out:
# array([[0.80874162, 0.40451382, 1.06979054, 0.60348164, 0.651087  ],
#        [0.39945932, 0.51329212, 0.77217589, 0.4242836 , 0.43036706],
#        [0.2264377 , 0.45790642, 0.34209517, 0.26870596, 0.21868301],
#        [0.21310729, 0.4908977 , 0.63838868, 0.37226429, 0.38758503],
#        [0.18129125, 0.45619105, 0.57685209, 0.28487688, 0.2843853 ]])

# %%
def get_auroc(y_pred_proba, y_true):
  res = metrics.roc_auc_score(y_true, y_pred_proba)
  return res

# %%
ps_score = [[] for _ in range(5)]

# %%
for sys in scoreSys:
  for seed in range(len(ps_score)):
    ps = get_auroc(globals()['predictions_valid_%s' % sys][seed], globals()['valid_y_%s'%str(seed+1)])
    ps_score[seed].append(ps)

# %%
ps_score
# Out:
# [[0.8851540616246498,
#   0.9677871148459384,
#   0.9663865546218486,
#   0.907563025210084,
#   0.8571428571428571],
#  [0.8018867924528301,
#   0.9283018867924528,
#   0.9849056603773585,
#   0.9886792452830189,
#   0.939622641509434],
#  [0.733974358974359,
#   0.9823717948717949,
#   0.9775641025641025,
#   0.9775641025641025,
#   0.8942307692307693],
#  [0.5833333333333333,
#   0.974537037037037,
#   0.9537037037037037,
#   0.9814814814814815,
#   0.9768518518518519],
#  [0.3057644110275689,
#   0.8934837092731829,
#   0.6942355889724311,
#   0.6541353383458647,
#   0.644110275689223]]

# %%
def powerset(s):
    x = len(s)
    ls = []
    for i in range(1 << x):
        ls.append([s[j] for j in range(x) if (i & (1 << j))])
    return ls[1:]

models = powerset(scoreSys)

def myFunc(e):
  return len(e)

models.sort(key=myFunc)

models_list = []
for i in range(len(models)):
  if len(models[i]) == 1:
    models_list.append(models[i][0])
  elif len(models[i]) == 2:
    models_list.append(models[i][0]+'&'+models[i][1])
  elif len(models[i]) == 3:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2])
  elif len(models[i]) == 4:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3])
  elif len(models[i]) == 5:
    models_list.append(models[i][0]+'&'+models[i][1]+'&'+models[i][2]+'&'+models[i][3]+'&'+models[i][4])

# %% [markdown]
# # Perform average score combinations

# %%
avg_score_combine_seed1 = pd.DataFrame({'xgb':predictions_test_xgb[0], 'rf':predictions_test_rf[0], 'svm':predictions_test_svm[0], 'adb':predictions_test_adb[0], 'cnn':predictions_test_cnn[0]})
avg_score_combine_seed2 = pd.DataFrame({'xgb':predictions_test_xgb[1], 'rf':predictions_test_rf[1], 'svm':predictions_test_svm[1], 'adb':predictions_test_adb[1], 'cnn':predictions_test_cnn[1]})
avg_score_combine_seed3 = pd.DataFrame({'xgb':predictions_test_xgb[2], 'rf':predictions_test_rf[2], 'svm':predictions_test_svm[2], 'adb':predictions_test_adb[2], 'cnn':predictions_test_cnn[2]})
avg_score_combine_seed4 = pd.DataFrame({'xgb':predictions_test_xgb[3], 'rf':predictions_test_rf[3], 'svm':predictions_test_svm[3], 'adb':predictions_test_adb[3], 'cnn':predictions_test_cnn[3]})
avg_score_combine_seed5 = pd.DataFrame({'xgb':predictions_test_xgb[4], 'rf':predictions_test_rf[4], 'svm':predictions_test_svm[4], 'adb':predictions_test_adb[4], 'cnn':predictions_test_cnn[4]})

# %%
def avg_score_combine(models_list, single_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_score[j] = (single_score[j.split('&')[0]]+single_score[j.split('&')[1]]+single_score[j.split('&')[2]]+single_score[j.split('&')[3]]+single_score[j.split('&')[4]]) / 5

# %%
avg_score_combine(models_list, avg_score_combine_seed1)
avg_score_combine(models_list, avg_score_combine_seed2)
avg_score_combine(models_list, avg_score_combine_seed3)
avg_score_combine(models_list, avg_score_combine_seed4)
avg_score_combine(models_list, avg_score_combine_seed5)

# %% [markdown]
# # Perform average rank combinations

# %%
def score_to_rank(array):
  res = np.argsort(np.flip(np.argsort(array)))+1
  return res

# %%
avg_rank_combine_seed1 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[0]), 'rf':score_to_rank(predictions_test_rf[0]), 'svm':score_to_rank(predictions_test_svm[0]), 'adb':score_to_rank(predictions_test_adb[0]), 'cnn':score_to_rank(predictions_test_cnn[0])})
avg_rank_combine_seed2 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[1]), 'rf':score_to_rank(predictions_test_rf[1]), 'svm':score_to_rank(predictions_test_svm[1]), 'adb':score_to_rank(predictions_test_adb[1]), 'cnn':score_to_rank(predictions_test_cnn[1])})
avg_rank_combine_seed3 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[2]), 'rf':score_to_rank(predictions_test_rf[2]), 'svm':score_to_rank(predictions_test_svm[2]), 'adb':score_to_rank(predictions_test_adb[2]), 'cnn':score_to_rank(predictions_test_cnn[2])})
avg_rank_combine_seed4 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[3]), 'rf':score_to_rank(predictions_test_rf[3]), 'svm':score_to_rank(predictions_test_svm[3]), 'adb':score_to_rank(predictions_test_adb[3]), 'cnn':score_to_rank(predictions_test_cnn[3])})
avg_rank_combine_seed5 = pd.DataFrame({'xgb':score_to_rank(predictions_test_xgb[4]), 'rf':score_to_rank(predictions_test_rf[4]), 'svm':score_to_rank(predictions_test_svm[4]), 'adb':score_to_rank(predictions_test_adb[4]), 'cnn':score_to_rank(predictions_test_cnn[4])})

# %%
def avg_rank_combine(models_list, single_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]) / 2
    elif len(j.split('&')) == 3:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]) / 3
    elif len(j.split('&')) == 4:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]) / 4
    elif len(j.split('&')) == 5:
      single_rank[j+'_r'] = (single_rank[j.split('&')[0]]+single_rank[j.split('&')[1]]+single_rank[j.split('&')[2]]+single_rank[j.split('&')[3]]+single_rank[j.split('&')[4]]) / 5

# %%
avg_rank_combine(models_list, avg_rank_combine_seed1)
avg_rank_combine(models_list, avg_rank_combine_seed2)
avg_rank_combine(models_list, avg_rank_combine_seed3)
avg_rank_combine(models_list, avg_rank_combine_seed4)
avg_rank_combine(models_list, avg_rank_combine_seed5)

# %% [markdown]
# # Perform weighted score combination by diversity strength

# %%
ds_score_combine_seed1 = pd.DataFrame()
ds_score_combine_seed2 = pd.DataFrame()
ds_score_combine_seed3 = pd.DataFrame()
ds_score_combine_seed4 = pd.DataFrame()
ds_score_combine_seed5 = pd.DataFrame()

# %%
def ds_score_combine(models_list, single_score, ds_score_combine, ds_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_score_combine[j+'_ds'] = (single_score[j.split('&')[0]]*ds_score[scoreSys.index(j.split('&')[0])]+single_score[j.split('&')[1]]*ds_score[scoreSys.index(j.split('&')[1])]+single_score[j.split('&')[2]]*ds_score[scoreSys.index(j.split('&')[2])]+single_score[j.split('&')[3]]*ds_score[scoreSys.index(j.split('&')[3])]+single_score[j.split('&')[4]]*ds_score[scoreSys.index(j.split('&')[4])])/(ds_score[scoreSys.index(j.split('&')[0])] + ds_score[scoreSys.index(j.split('&')[1])] + ds_score[scoreSys.index(j.split('&')[2])] + ds_score[scoreSys.index(j.split('&')[3])] + ds_score[scoreSys.index(j.split('&')[4])])

# %%
ds_score_combine(models_list, avg_score_combine_seed1, ds_score_combine_seed1, ds_score[0])
ds_score_combine(models_list, avg_score_combine_seed2, ds_score_combine_seed2, ds_score[1])
ds_score_combine(models_list, avg_score_combine_seed3, ds_score_combine_seed3, ds_score[2])
ds_score_combine(models_list, avg_score_combine_seed4, ds_score_combine_seed4, ds_score[3])
ds_score_combine(models_list, avg_score_combine_seed5, ds_score_combine_seed5, ds_score[4])

# %% [markdown]
# # Perform weighted rank combination by diversity strength

# %%
ds_rank_combine_seed1 = pd.DataFrame()
ds_rank_combine_seed2 = pd.DataFrame()
ds_rank_combine_seed3 = pd.DataFrame()
ds_rank_combine_seed4 = pd.DataFrame()
ds_rank_combine_seed5 = pd.DataFrame()

# %%
def ds_rank_combine(models_list, single_rank, ds_rank_combine, ds_rank):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ds_rank_combine[j+'_ds_r'] = (single_rank[j.split('&')[0]]*ds_rank[scoreSys.index(j.split('&')[0])]+single_rank[j.split('&')[1]]*ds_rank[scoreSys.index(j.split('&')[1])]+single_rank[j.split('&')[2]]*ds_rank[scoreSys.index(j.split('&')[2])]+single_rank[j.split('&')[3]]*ds_rank[scoreSys.index(j.split('&')[3])]+single_rank[j.split('&')[4]]*ds_rank[scoreSys.index(j.split('&')[4])])/(ds_rank[scoreSys.index(j.split('&')[0])] + ds_rank[scoreSys.index(j.split('&')[1])] + ds_rank[scoreSys.index(j.split('&')[2])] + ds_rank[scoreSys.index(j.split('&')[3])] + ds_rank[scoreSys.index(j.split('&')[4])])

# %%
ds_rank_combine(models_list, avg_rank_combine_seed1, ds_rank_combine_seed1, ds_rank[0])
ds_rank_combine(models_list, avg_rank_combine_seed2, ds_rank_combine_seed2, ds_rank[1])
ds_rank_combine(models_list, avg_rank_combine_seed3, ds_rank_combine_seed3, ds_rank[2])
ds_rank_combine(models_list, avg_rank_combine_seed4, ds_rank_combine_seed4, ds_rank[3])
ds_rank_combine(models_list, avg_rank_combine_seed5, ds_rank_combine_seed5, ds_rank[4])

# %% [markdown]
# # Perform weighted score combination by performance strength (AUROC)

# %%
ps_score_combine_seed1 = pd.DataFrame()
ps_score_combine_seed2 = pd.DataFrame()
ps_score_combine_seed3 = pd.DataFrame()
ps_score_combine_seed4 = pd.DataFrame()
ps_score_combine_seed5 = pd.DataFrame()

# %%
def ps_score_combine(models_list, single_score, ps_score_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_score_combine[j+'_ps'] = (single_score[j.split('&')[0]]*(ps_score[scoreSys.index(j.split('&')[0])])+single_score[j.split('&')[1]]*(ps_score[scoreSys.index(j.split('&')[1])])+single_score[j.split('&')[2]]*(ps_score[scoreSys.index(j.split('&')[2])])+single_score[j.split('&')[3]]*(ps_score[scoreSys.index(j.split('&')[3])])+single_score[j.split('&')[4]]*(ps_score[scoreSys.index(j.split('&')[4])]))/(ps_score[scoreSys.index(j.split('&')[0])] + ps_score[scoreSys.index(j.split('&')[1])] + ps_score[scoreSys.index(j.split('&')[2])] + ps_score[scoreSys.index(j.split('&')[3])] + ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_score_combine(models_list, avg_score_combine_seed1, ps_score_combine_seed1, ps_score[0])
ps_score_combine(models_list, avg_score_combine_seed2, ps_score_combine_seed2, ps_score[1])
ps_score_combine(models_list, avg_score_combine_seed3, ps_score_combine_seed3, ps_score[2])
ps_score_combine(models_list, avg_score_combine_seed4, ps_score_combine_seed4, ps_score[3])
ps_score_combine(models_list, avg_score_combine_seed5, ps_score_combine_seed5, ps_score[4])

# %% [markdown]
# # Perform weighted rank combination by performance strength

# %%
ps_rank_combine_seed1 = pd.DataFrame()
ps_rank_combine_seed2 = pd.DataFrame()
ps_rank_combine_seed3 = pd.DataFrame()
ps_rank_combine_seed4 = pd.DataFrame()
ps_rank_combine_seed5 = pd.DataFrame()

# %%
def ps_rank_combine(models_list, single_rank, ps_rank_combine, ps_score):
  for j in models_list[len(scoreSys):]:
    if len(j.split('&')) == 2:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])])
    elif len(j.split('&')) == 3:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])])
    elif len(j.split('&')) == 4:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + 1 / ps_score[scoreSys.index(j.split('&')[3])])
    elif len(j.split('&')) == 5:
      ps_rank_combine[j+'_ps_r'] = (single_rank[j.split('&')[0]]*(1 / ps_score[scoreSys.index(j.split('&')[0])])+single_rank[j.split('&')[1]]*(1 / ps_score[scoreSys.index(j.split('&')[1])])+single_rank[j.split('&')[2]]*(1 / ps_score[scoreSys.index(j.split('&')[2])])+single_rank[j.split('&')[3]]*(1 / ps_score[scoreSys.index(j.split('&')[3])])+single_rank[j.split('&')[4]]*(1 / ps_score[scoreSys.index(j.split('&')[4])]))/(1 / ps_score[scoreSys.index(j.split('&')[0])] + 1 / ps_score[scoreSys.index(j.split('&')[1])] + 1 / ps_score[scoreSys.index(j.split('&')[2])] + 1 / ps_score[scoreSys.index(j.split('&')[3])] + 1 / ps_score[scoreSys.index(j.split('&')[4])])

# %%
ps_rank_combine(models_list, avg_rank_combine_seed1, ps_rank_combine_seed1, ps_score[0])
ps_rank_combine(models_list, avg_rank_combine_seed2, ps_rank_combine_seed2, ps_score[1])
ps_rank_combine(models_list, avg_rank_combine_seed3, ps_rank_combine_seed3, ps_score[2])
ps_rank_combine(models_list, avg_rank_combine_seed4, ps_rank_combine_seed4, ps_score[3])
ps_rank_combine(models_list, avg_rank_combine_seed5, ps_rank_combine_seed5, ps_score[4])

# %%
avg_rank_combine_seed1.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed2.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed3.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed4.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)
avg_rank_combine_seed5.rename(columns={'xgb': 'xgb_r', 'rf': 'rf_r', 'svm': 'svm_r', 'adb': 'adb_r', 'cnn': 'cnn_r'}, inplace=True)

# %% [markdown]
# # Calculate AUROC

# %%
score_combine_list = np.hstack((np.array(avg_score_combine_seed1.columns), np.array(ds_score_combine_seed1.columns), np.array(ps_score_combine_seed1.columns)))
AUROC = pd.DataFrame(index = score_combine_list)
for i in range(1, 6):
  auroc_avg, auroc_ds, auroc_ps = [], [], []
  for col in globals()['avg_score_combine_seed%s' %i].columns:
    auroc_score = get_auroc(np.array(globals()['avg_score_combine_seed%s' %i][col]), y_test)
    auroc_avg.append(auroc_score)
  for col in globals()['ds_score_combine_seed%s' %i].columns:
    auroc_score = get_auroc(np.array(globals()['ds_score_combine_seed%s' %i][col]), y_test)
    auroc_ds.append(auroc_score)
  for col in globals()['ps_score_combine_seed%s' %i].columns:
    auroc_score = get_auroc(np.array(globals()['ps_score_combine_seed%s' %i][col]), y_test)
    auroc_ps.append(auroc_score)
  AUROC['seed'+str(i)] = np.hstack((auroc_avg, auroc_ds, auroc_ps))

# %%
pd.set_option('display.max_rows', None)

# %%
AUROC['avg_AUROC'] = AUROC.mean(axis=1)

# %%
AUROC.sort_values(by='avg_AUROC', ascending=False)
# Out:
#                           seed1     seed2     seed3     seed4     seed5  \
# xgb&rf&svm&adb_ps      0.961728  0.956379  0.956790  0.967901  0.957613
# rf&svm&adb_ds          0.959671  0.952675  0.955144  0.971605  0.960905
# xgb&rf&svm&adb         0.961728  0.955967  0.957613  0.966667  0.954321
# rf&svm&adb             0.959671  0.951852  0.955967  0.967901  0.960082
# rf&svm&adb_ps          0.959259  0.951440  0.956379  0.968313  0.955144
# xgb&rf&svm&adb_ds      0.966255  0.957613  0.955144  0.957202  0.944033
# xgb&rf&svm&adb&cnn_ps  0.951852  0.952263  0.951440  0.960082  0.955967
# svm&adb_ds             0.945267  0.955144  0.949794  0.964609  0.956790
# xgb&rf&svm&adb&cnn     0.949383  0.951852  0.951029  0.958848  0.955967
# rf&svm&adb&cnn_ds      0.952263  0.947325  0.948148  0.960494  0.957613
# rf&svm&adb&cnn         0.946502  0.948148  0.948971  0.960082  0.959671
# rf&svm&adb&cnn_ps      0.947737  0.948148  0.949383  0.960082  0.955556
# xgb&rf&svm&adb&cnn_ds  0.957202  0.953909  0.947737  0.948560  0.950206
# xgb&rf&svm_ps          0.949794  0.946502  0.952263  0.956790  0.951029
# xgb&svm&adb_ps         0.946914  0.953498  0.950206  0.953498  0.951852
# xgb&rf&svm             0.950206  0.945267  0.953086  0.954733  0.950617
# rf&svm                 0.950206  0.941975  0.950617  0.960082  0.950206
# svm&adb                0.941152  0.949794  0.948560  0.960494  0.953086
# adb                    0.923045  0.960494  0.939095  0.970370  0.959671
# svm&adb_ps             0.940329  0.949794  0.948560  0.961317  0.952263
# rf&svm_ps              0.950206  0.941564  0.950617  0.960082  0.948971
# xgb&svm&adb            0.947737  0.952263  0.950617  0.948971  0.946914
# rf&svm_ds              0.944856  0.941152  0.951852  0.958848  0.949794
# xgb&rf&adb&cnn         0.952263  0.944444  0.937449  0.958848  0.946914
# xgb&rf&adb             0.963374  0.948148  0.921811  0.962140  0.940741
# svm&adb&cnn_ds         0.933745  0.949383  0.945267  0.953909  0.953086
# xgb&rf&svm&cnn_ps      0.940329  0.944033  0.948971  0.947325  0.954321
# xgb&rf&adb&cnn_ps      0.953909  0.944856  0.934568  0.960905  0.939918
# xgb&rf&adb&cnn_ds      0.953909  0.947737  0.941564  0.946091  0.943621
# xgb&rf&adb_ps          0.962551  0.948148  0.916049  0.965432  0.939506
# xgb&rf&svm&cnn         0.939918  0.942387  0.949383  0.946914  0.952675
# xgb&svm&adb&cnn_ps     0.932510  0.948148  0.948560  0.944856  0.953086
# xgb&rf&svm_ds          0.951440  0.946091  0.950617  0.942798  0.936214
# svm&adb&cnn_ps         0.929630  0.945679  0.945267  0.951852  0.953909
# xgb&svm&adb_ds         0.951440  0.951440  0.949794  0.945267  0.928395
# svm&adb&cnn            0.930453  0.945267  0.945679  0.951440  0.953086
# rf&svm&cnn             0.936626  0.938272  0.946502  0.948971  0.952675
# xgb&rf&adb_ds          0.960082  0.951852  0.930864  0.952675  0.926749
# rf&svm&cnn_ps          0.935802  0.938272  0.947325  0.948971  0.948971
# rf&adb&cnn_ds          0.945267  0.934568  0.928807  0.961728  0.946914
# rf&svm&cnn_ds          0.940329  0.935391  0.944444  0.944856  0.951440
# xgb&svm&adb&cnn        0.932510  0.946502  0.946914  0.939918  0.950617
# xgb&rf&svm&cnn_ds      0.945267  0.941152  0.946091  0.935391  0.945679
# rf&adb_ds              0.948971  0.938683  0.905761  0.970782  0.948971
# rf&adb&cnn             0.946502  0.933745  0.927572  0.961728  0.943210
# rf&adb&cnn_ps          0.946502  0.934568  0.927160  0.962140  0.939918
# xgb&adb_ps             0.953498  0.947737  0.932099  0.948971  0.920576
# rf&adb                 0.954733  0.937037  0.897119  0.968313  0.942798
# adb&cnn_ds             0.918107  0.953498  0.925103  0.951852  0.949794
# adb&cnn_ps             0.917695  0.953498  0.925514  0.951440  0.949794
# adb&cnn                0.917695  0.953086  0.925514  0.951440  0.949794
# xgb&svm&adb&cnn_ds     0.935391  0.944444  0.943621  0.935802  0.936214
# rf&adb_ps              0.955144  0.937449  0.897119  0.968313  0.937449
# xgb&rf&cnn             0.936626  0.933333  0.934979  0.944033  0.938272
# xgb&rf&cnn_ps          0.937860  0.933333  0.934156  0.944444  0.936214
# xgb&adb&cnn_ps         0.930864  0.941975  0.935802  0.934568  0.935391
# xgb&rf&cnn_ds          0.938683  0.932510  0.940741  0.929218  0.936214
# xgb&adb                0.953086  0.948148  0.928395  0.948971  0.897942
# xgb&svm_ps             0.928807  0.931276  0.939506  0.931687  0.944033
# xgb&adb&cnn            0.930453  0.941975  0.935802  0.935391  0.928395
# xgb&svm                0.927984  0.932510  0.941564  0.925514  0.938683
# xgb&adb&cnn_ds         0.931276  0.941564  0.932922  0.934568  0.924691
# svm                    0.914815  0.930041  0.934156  0.937037  0.943210
# xgb&svm&cnn_ps         0.916049  0.929630  0.940741  0.923868  0.946914
# rf&cnn                 0.927572  0.920165  0.926337  0.945267  0.933745
# rf&cnn_ds              0.930041  0.917284  0.927160  0.943621  0.933333
# svm&cnn_ps             0.904527  0.929630  0.935802  0.931276  0.948560
# rf&cnn_ps              0.928807  0.920165  0.923457  0.945267  0.931687
# svm&cnn                0.904938  0.929218  0.936626  0.930453  0.947737
# xgb&adb_ds             0.954733  0.948148  0.921399  0.942798  0.881070
# xgb&svm&cnn            0.914815  0.929630  0.941152  0.917695  0.944856
# svm&cnn_ds             0.902058  0.927984  0.934568  0.930453  0.945679
# xgb&rf_ps              0.923457  0.930864  0.907407  0.940329  0.926749
# xgb&svm_ds             0.929218  0.928395  0.938683  0.910700  0.911111
# xgb&svm&cnn_ds         0.912346  0.925926  0.937037  0.907819  0.929218
# xgb&rf                 0.924280  0.929630  0.908642  0.932922  0.915226
# rf                     0.919136  0.920782  0.892387  0.940741  0.919959
# xgb&rf_ds              0.925103  0.929630  0.920165  0.903704  0.891358
# xgb&cnn_ps             0.890947  0.899177  0.925926  0.890947  0.915638
# xgb&cnn                0.890947  0.900000  0.926337  0.890123  0.913992
# xgb&cnn_ds             0.889300  0.900412  0.926337  0.883128  0.912346
# cnn                    0.847325  0.866872  0.873045  0.885597  0.890947
# xgb                    0.812757  0.819959  0.833128  0.768930  0.800206
#
#                        avg_AUROC
# xgb&rf&svm&adb_ps       0.960082
# rf&svm&adb_ds           0.960000
# xgb&rf&svm&adb          0.959259
# rf&svm&adb              0.959095
# rf&svm&adb_ps           0.958107
# xgb&rf&svm&adb_ds       0.956049
# xgb&rf&svm&adb&cnn_ps   0.954321
# svm&adb_ds              0.954321
# xgb&rf&svm&adb&cnn      0.953416
# rf&svm&adb&cnn_ds       0.953169
# rf&svm&adb&cnn          0.952675
# rf&svm&adb&cnn_ps       0.952181
# xgb&rf&svm&adb&cnn_ds   0.951523
# xgb&rf&svm_ps           0.951276
# xgb&svm&adb_ps          0.951193
# xgb&rf&svm              0.950782
# rf&svm                  0.950617
# svm&adb                 0.950617
# adb                     0.950535
# svm&adb_ps              0.950453
# rf&svm_ps               0.950288
# xgb&svm&adb             0.949300
# rf&svm_ds               0.949300
# xgb&rf&adb&cnn          0.947984
# xgb&rf&adb              0.947243
# svm&adb&cnn_ds          0.947078
# xgb&rf&svm&cnn_ps       0.946996
# xgb&rf&adb&cnn_ps       0.946831
# xgb&rf&adb&cnn_ds       0.946584
# xgb&rf&adb_ps           0.946337
# xgb&rf&svm&cnn          0.946255
# xgb&svm&adb&cnn_ps      0.945432
# xgb&rf&svm_ds           0.945432
# svm&adb&cnn_ps          0.945267
# xgb&svm&adb_ds          0.945267
# svm&adb&cnn             0.945185
# rf&svm&cnn              0.944609
# xgb&rf&adb_ds           0.944444
# rf&svm&cnn_ps           0.943868
# rf&adb&cnn_ds           0.943457
# rf&svm&cnn_ds           0.943292
# xgb&svm&adb&cnn         0.943292
# xgb&rf&svm&cnn_ds       0.942716
# rf&adb_ds               0.942634
# rf&adb&cnn              0.942551
# rf&adb&cnn_ps           0.942058
# xgb&adb_ps              0.940576
# rf&adb                  0.940000
# adb&cnn_ds              0.939671
# adb&cnn_ps              0.939588
# adb&cnn                 0.939506
# xgb&svm&adb&cnn_ds      0.939095
# rf&adb_ps               0.939095
# xgb&rf&cnn              0.937449
# xgb&rf&cnn_ps           0.937202
# xgb&adb&cnn_ps          0.935720
# xgb&rf&cnn_ds           0.935473
# xgb&adb                 0.935309
# xgb&svm_ps              0.935062
# xgb&adb&cnn             0.934403
# xgb&svm                 0.933251
# xgb&adb&cnn_ds          0.933004
# svm                     0.931852
# xgb&svm&cnn_ps          0.931440
# rf&cnn                  0.930617
# rf&cnn_ds               0.930288
# svm&cnn_ps              0.929959
# rf&cnn_ps               0.929877
# svm&cnn                 0.929794
# xgb&adb_ds              0.929630
# xgb&svm&cnn             0.929630
# svm&cnn_ds              0.928148
# xgb&rf_ps               0.925761
# xgb&svm_ds              0.923621
# xgb&svm&cnn_ds          0.922469
# xgb&rf                  0.922140
# rf                      0.918601
# xgb&rf_ds               0.913992
# xgb&cnn_ps              0.904527
# xgb&cnn                 0.904280
# xgb&cnn_ds              0.902305
# cnn                     0.872757
# xgb                     0.806996
